# %% [markdown]
# # ***Блок подготовки библиотек***

# %% [markdown]
# ### Установка библиотек

# %%
# !pip install ortools
# !pip install scikit-learn-extra
# Out:
# Collecting ortools
#   Downloading ortools-9.8.3296-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.9/22.9 MB 36.2 MB/s eta 0:00:00
# Collecting absl-py>=2.0.0 (from ortools)
#   Downloading absl_py-2.0.0-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from ortools) (1.23.5)
# Collecting pandas>=2.0.0 (from ortools)
#   Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 42.7 MB/s eta 0:00:00
# Collecting protobuf>=4.25.0 (from ortools)
#   Downloading protobuf-4.25.1-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->ortools) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->ortools) (2023.3.post1)
# Collecting tzdata>=2022.1 (from pandas>=2.0.0->ortools)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 22.7 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->ortools) (1.16.0)
# Installing collected packages: tzdata, protobuf, absl-py, pandas, ortools
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.4.0
#     Uninstalling absl-py-1.4.0:
#       Successfully uninstalled absl-py-1.4.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# bigframes 0.17.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 2.1.4 which is incompatible.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.1.4 which is incompatible.
# tensorboard 2.15.1 requires protobuf<4.24,>=3.19.6, but you have protobuf 4.25.1 which is incompatible.
# tensorflow-metadata 1.14.0 requires absl-py<2.0.0,>=0.9, but you have absl-py 2.0.0 which is incompatible.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.25.1 which is incompatible.
# Successfully installed absl-py-2.0.0 ortools-9.8.3296 pandas-2.1.4 protobuf-4.25.1 tzdata-2023.3
# Collecting scikit-learn-extra
#   Downloading scikit_learn_extra-0.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn-extra) (1.23.5)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn-extra) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn-extra) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (3.2.0)
# Installing collected packages: scikit-learn-extra
# Successfully installed scikit-learn-extra-0.3.0

# %% [markdown]
# ### Импорт библиотек

# %%
import time
import math
import folium
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.spatial.distance import cdist
from sklearn_extra.cluster import KMedoids
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, MiniBatchKMeans
from ortools.constraint_solver import pywrapcp, routing_enums_pb2
from ortools.graph.python import min_cost_flow, max_flow, linear_sum_assignment

# %% [markdown]
# # ***Функции***

# %% [markdown]
# ### Расчет расстояния между точками

# %%
def custom_distance(coord1, coord2):
    return haversine(coord1[0],coord1[1],coord2[0],coord2[1])

def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance in kilometers between two points
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians
    lon1, lat1, lon2, lat2 = map(math.radians, [lon1, lat1, lon2, lat2])
    # haversine formula
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = math.sin(dlat/2)**2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon/2)**2
    c = 2 * math.asin(math.sqrt(a))
    r = 6371 # Radius of earth in kilometers
    return c * r * 1000

# %% [markdown]
# ### Поиск оптимального количества кластеров и работа с кластерами

# %%
# Поиск оптимального количества кластеров, с которыми будем работать
def search_KMedoids(graph, n_start=3, n_end=50):
    nodes_coord = np.array([(coord['lon'], coord['lat']) for i, coord in graph.nodes(data=True)])
    scaler = StandardScaler().fit(nodes_coord)
    x_scaled = scaler.transform(nodes_coord)

    inertias = []
    for i in range(n_start, n_end+1):
        kMedoids = KMedoids(n_clusters=i, random_state=42, method='pam')
        kMedoids.fit(x_scaled)
        inertias.append(kMedoids.inertia_)
    plt.figure(figsize=(5, 3))
    plt.scatter([i for i in range(n_start, n_end+1)], inertias)


# Добавление номера кластера к узлу
def add_cluster_info_to_graph(graph, clusters):
    for cluster_num, nodes in clusters.items():
        for node in nodes:
            graph.nodes[node]['cluster_number'] = cluster_num
    return graph


# Разделение точек на кластеры
def kmedoids_clustering_for_graph(graph, num_clusters=5):
    nodes_coord = np.array([(coord['lon'], coord['lat']) for i, coord in graph.nodes(data=True)])
    scaler = StandardScaler().fit(nodes_coord)
    x_scaled = scaler.transform(nodes_coord)
    kmedoids = KMedoids(n_clusters=num_clusters, method='pam', random_state=42).fit(x_scaled)
    labels = kmedoids.labels_
    medoid_indices = kmedoids.medoid_indices_

    clusters = {}
    for i, label in enumerate(labels):
        if label not in clusters:
            clusters[label] = []
        clusters[label].append(i)

    output_graph = add_cluster_info_to_graph(graph, clusters)
    return output_graph, medoid_indices


# Выделение подграфа на основе кластера
def extract_cluster_subgraph(graph, cluster_number_to_extract):
    nodes_to_keep = [node for node, data in graph.nodes(data=True) if data['cluster_number'] == cluster_number_to_extract]
    subgraph = graph.subgraph(nodes_to_keep)
    return subgraph

# %% [markdown]
# ### Вывод результата OR-Tools

# %%
def print_solution(data, manager, routing, solution):
    """Prints solution on console."""
    print(f"Objective: {solution.ObjectiveValue()}")
    max_route_distance = 0
    for vehicle_id in range(data["num_vehicles"]):
        index = routing.Start(vehicle_id)
        plan_output = f"Route for vehicle {vehicle_id}:\n"
        route_distance = 0
        while not routing.IsEnd(index):
            plan_output += f" {manager.IndexToNode(index)} -> "
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(
                previous_index, index, vehicle_id
            )
        plan_output += f"{manager.IndexToNode(index)}\n"
        plan_output += f"Distance of the route: {route_distance}m\n"
        print(plan_output)
        max_route_distance = max(route_distance, max_route_distance)
    print(f"Maximum of the route distances: {max_route_distance}m - {max_route_distance/1000}km")



#
def get_routes(solution, routing, manager):
    """Get vehicle routes from a solution and store them in an array."""
    # Get vehicle routes and store them in a two dimensional array whose
    # i,j entry is the jth location visited by vehicle i along its route.
    routes = []
    for route_nbr in range(routing.vehicles()):
        index = routing.Start(route_nbr)
        route = [manager.IndexToNode(index)]
        while not routing.IsEnd(index):
            index = solution.Value(routing.NextVar(index))
            route.append(manager.IndexToNode(index))
        routes.append(route)
    return routes

# %% [markdown]
# ### Поиск наименьшего расстояния между соседними кластерами

# %%
def search_min_weight_path(graph, clusters):
    transition = {}
    # Здесь идет перебор соседних кластеров, выделение подграфа,
    # удаление ребер между точками в одном кластере,
    # поиск наименьшего пути между точками
    for i in range(-1, len(correct_clusters) - 1):
        selected_nodes = [node for node, attr in work_graph.nodes(data=True) if attr['cluster_number'] in (correct_clusters[i], correct_clusters[i+1])]
        subgraph = work_graph.subgraph(selected_nodes).copy()
        for u, v in subgraph.edges():
            if subgraph.nodes[u]['cluster_number'] == subgraph.nodes[v]['cluster_number']:
                subgraph.remove_edge(u, v)
        node = min(subgraph.edges(data=True), key=lambda x: x[2]['weight'])
        if subgraph.nodes[node[0]]['cluster_number'] == correct_clusters[i]:
            transition[correct_clusters[i], correct_clusters[i+1]] = (node[0], node[1])
        else:
            transition[correct_clusters[i], correct_clusters[i+1]] = (node[1], node[0])

    # Данный словарь хранит начальную и конечную точку каждого кластера
    extreme_points = {}
    for i in range(-2, len(correct_clusters) - 2):
        extreme_points[correct_clusters[i+1]] = ([transition[(correct_clusters[i], correct_clusters[i+1])][1], transition[(correct_clusters[i+1], correct_clusters[i+2])][0]])

    return transition, extreme_points

# %% [markdown]
# ### Поиск оптимального пути графа

# %%
# создание матрицы на основе полного графа
def create_matrix_from_graph(graph):
    # max_distance = 4294967295
    max_distance = 0
    matrix = np.full((len(graph.nodes()), len(graph.nodes())), max_distance)
    max_weight = max(graph.edges(data=True), key=lambda x: x[2]['weight'])
    for u, v, weight in graph.edges(data=True):
        weight = weight['weight']
        matrix[u][v] = weight
        matrix[v][u] = weight
    return matrix, max_weight


# создание словаря данных для OR-Tools
def create_data_model(graph, start=0, end=0):
    """Stores the data for the problem."""
    data = {}
    matrix_from_graph, max_weight = create_matrix_from_graph(graph)
    data["distance_matrix"] = matrix_from_graph
    data["num_vehicles"] = 1
    data["starts"] = [max_weight[0]]
    data["ends"] = [max_weight[1]]
    return data


def create_data_model_for_clusters(graph, start=0, end=0, extreme=False):
    """Stores the data for the problem."""
    data = {}
    matrix_G = matrix_from_graph(graph)
    nodes = [node for node, attr in graph.nodes(data=True)]
    index_mapping = {index: i for i, index in enumerate(nodes)}
    data["distance_matrix"] = matrix_G
    data["num_vehicles"] = 1
    if isinstance(extreme, list):
        data["starts"] = [index_mapping[extreme[0]]]
        data["ends"] = [index_mapping[extreme[1]]]
    else:
        max_index = np.unravel_index(np.argmax(matrix_G), matrix_G.shape)
        row_index, col_index = max_index
        data["starts"] = [int(row_index)]
        data["ends"] = [int(col_index)]
    return data


# Поиск оптимального пути на основе полного графа
def search_optimal_path(graph, clusters=False, timeout=False, dimension=False, extreme=False):
    if clusters:
        data = create_data_model_for_clusters(graph, extreme=extreme)
    else:
        data = create_data_model(graph)
    manager = pywrapcp.RoutingIndexManager(len(data["distance_matrix"]), data["num_vehicles"], data["starts"], data["ends"])
    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        """Returns the distance between the two nodes."""
        # Convert from routing variable Index to distance matrix NodeIndex.
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return data["distance_matrix"][from_node][to_node]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)
    if dimension:
        dimension_name = "Distance"
        routing.AddDimension(
            transit_callback_index,
            0,  # no slack
            1800000,  # vehicle maximum travel distance
            True,  # start cumul to zero
            dimension_name,)
        distance_dimension = routing.GetDimensionOrDie(dimension_name)
        distance_dimension.SetGlobalSpanCostCoefficient(100)
    # Setting first solution heuristic.
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    # search_parameters.first_solution_strategy = (routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)
    if timeout:
        search_parameters.time_limit.seconds = timeout
    # solution = routing.SolveWithParameters(search_parameters)
    # if solution:
    # #     # print_solution(data, manager, routing, solution)
    #     routes = get_routes(solution, routing, manager)[0]
    search_parameters.local_search_metaheuristic = (routing_enums_pb2.LocalSearchMetaheuristic.SIMULATED_ANNEALING)
    solution = routing.SolveWithParameters(search_parameters)
    if solution:
        # print_solution(data, manager, routing, solution)
        routes = get_routes(solution, routing, manager)[0]
    return routes, solution.ObjectiveValue()

# %% [markdown]
# ### Создание графа из df

# %%
# Данный граф создает все маршруты между точками.
def create_graph_from_coordinates(df, threshold_distance=1700000, distance_bool=False):
    '''Создание графа между точками
       threshold_distance - максимальное расстояние между точками для создания узла (в метрах)
       distance           - учитывать ли дистанцию между точками
    '''
    G = nx.Graph()
    coordinates = list(zip(df['lon'], df['lat']))
    total_coordinates = len(coordinates)

    for idx, coord in enumerate(coordinates):
        G.add_node(idx, lon=coordinates[idx][0], lat=coordinates[idx][1])

    for i in tqdm(range(total_coordinates), desc="Progress"):
        for j in range(i + 1, total_coordinates):
            distance = int(haversine(coordinates[i][0], coordinates[i][1], coordinates[j][0], coordinates[j][1]))
            if distance_bool:
                if distance <= threshold_distance:
                    G.add_edge(i, j, weight=distance)
            else:
                G.add_edge(i, j, weight=distance)
    return G

# %% [markdown]
# ### Сборка графа на основе точек по поиска пути

# %%
def create_graph_after_solver(graph, routes):
    new_G = nx.Graph()
    for node in routes:
        # Копирование атрибутов узла из оригинального графа G в новый граф new_G
        if node in graph.nodes():
            new_G.add_node(node, **graph.nodes[node])
    for i in range(len(routes) - 1):
        node1 = routes[i]
        node2 = routes[i + 1]
        if graph.has_edge(node1, node2):
            # Копирование атрибутов ребра из оригинального графа G в новый граф new_G
            new_G.add_edge(node1, node2, **graph.get_edge_data(node1, node2))
        # else:
        #     new_G.add_edge(node1, node2, weight=40000000)
    return new_G

# %% [markdown]
# ### Матрица из графа

# %%
def matrix_from_graph(graph):
    return nx.floyd_warshall_numpy(graph).astype(np.int32)

# %% [markdown]
# ### Создание матрицы по кластерам

# %%
def create_graph_after_solver_full(graph, full_graph, routes):
    for node in routes:
        # Копирование атрибутов узла из оригинального графа G в новый граф new_G
        if node in graph.nodes():
            full_graph.add_node(node, **graph.nodes[node])
    for i in range(len(routes) - 1):
        node1 = routes[i]
        node2 = routes[i + 1]
        if graph.has_edge(node1, node2):
            # Копирование атрибутов ребра из оригинального графа G в новый граф new_G
            full_graph.add_edge(node1, node2, **graph.get_edge_data(node1, node2))
        # else:
        #     new_G.add_edge(node1, node2, weight=40000000)
    return full_graph

# %% [markdown]
# ### Создание интерактивной карты на основе графа

# %%
def create_map_from_graph(G):
    '''Создание интерактивной карты из графа. Граф должен иметь lat= и lon='''

    m = folium.Map(location=[56.322, 90.004], zoom_start=3)

    node_positions = {}
    node_positions = {node: (G.nodes[node]['lat'], G.nodes[node]['lon']) for node in G.nodes()}

    for node, pos in node_positions.items():
        folium.CircleMarker(location=pos, radius=0.1, color='blue', fill=True).add_to(m)


    for u, v, weight in G.edges(data=True):
        weight = weight['weight']
        pos_u = node_positions[u]
        pos_v = node_positions[v]
        if not weight:
            folium.PolyLine(locations=[pos_u, pos_v], color='red', weight=0.9, opacity=0.5).add_to(m)
        else:
            folium.PolyLine(locations=[pos_u, pos_v], color='black', weight=0.9, opacity=0.5).add_to(m)

    return m

# %% [markdown]
# # ***Подготовка данных***

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Чтение df

# %%
df = pd.read_csv('/content/drive/MyDrive/ВУЗ/ITMO/NIR/random_points.csv')
df = df.dropna()[['Долгота', 'Широта']].reset_index(drop=True)
df.columns = ['lon', 'lat']

# %%
work_df = df[::1000].copy()                # Если брать каждую (127*целое число) точку, то я захватываю всю территорию России
work_df = work_df.reset_index(drop=True)

# %% [markdown]
# ### Создание графа

# %%
# Данный граф создает все маршруты между точками.
def create_graph_from_coordinates(df, threshold_distance=1700000, distance_bool=False):
    '''Создание графа между точками
       threshold_distance - максимальное расстояние между точками для создания узла (в метрах)
       distance           - учитывать ли дистанцию между точками
    '''
    G = nx.Graph()
    coordinates = list(zip(df['lon'], df['lat']))
    total_coordinates = len(coordinates)

    for idx, coord in enumerate(coordinates):
        G.add_node(idx, lon=coordinates[idx][0], lat=coordinates[idx][1])

    for i in tqdm(range(total_coordinates), desc="Progress"):
        for j in range(i + 1, total_coordinates):
            distance = int(haversine(coordinates[i][0], coordinates[i][1], coordinates[j][0], coordinates[j][1]))
            if distance_bool:
                if distance <= threshold_distance:
                    G.add_edge(i, j, weight=distance)
            else:
                G.add_edge(i, j, weight=distance)
    return G

# %%
G = create_graph_from_coordinates(work_df)
# Out:
# Progress: 100%|██████████| 1211/1211 [00:02<00:00, 440.68it/s]

# %% [markdown]
# # ***Рабочая область***

# %%
# Поиск оптимального пути на всем графе. Вывод показывает
# 1. Маршрут с помощью ближайших соседей
# 2. Локальный поиск
# routes хранит в себе точки в порядке следования
routes, v = search_optimal_path(G, timeout=3600)

# Потребовалось 10 сек на 239 точек - 30497.36km лучший вариант
# Out:
# Objective: 54486070
# Route for vehicle 0:
#  3433 ->  3430 ->  3434 ->  3419 ->  3432 ->  3429 ->  3420 ->  3424 ->  3416 ->  3425 ->  3428 ->  3427 ->  3423 ->  3417 ->  3421 ->  3426 ->  3431 ->  3422 ->  3418 ->  3435 ->  3436 ->  3437 ->  4077 ->  4076 ->  4072 ->  4073 ->  4075 ->  4074 ->  4078 ->  2337 ->  2327 ->  2312 ->  2318 ->  2309 ->  2317 ->  2333 ->  2335 ->  2336 ->  2326 ->  2328 ->  2320 ->  2308 ->  2313 ->  2311 ->  2321 ->  2310 ->  2332 ->  2325 ->  2331 ->  2314 ->  2334 ->  2316 ->  2324 ->  2329 ->  2319 ->  2330 ->  2322 ->  2323 ->  2315 ->  1865 ->  1853 ->  1864 ->  4885 ->  1854 ->  1858 ->  1866 ->  1850 ->  1857 ->  1859 ->  4882 ->  4886 ->  1861 ->  1863 ->  1855 ->  1867 ->  1862 ->  1860 ->  4884 ->  1852 ->  1856 ->  1851 ->  4883 ->  1868 ->  1869 ->  1870 ->  1871 ->  1873 ->  2269 ->  1872 ->  2545 ->  2530 ->  2511 ->  2519 ->  2506 ->  2535 ->  2537 ->  2515 ->  2523 ->  2502 ->  2543 ->  2539 ->  2524 ->  2510 ->  2526 ->  2533 ->  2508 ->  2534 ->  2527 ->  2499 ->  2501 ->  2500 ->  2507 ->  2516 ->  2541 ->  2542 ->  2505 ->  2529 ->  2503 ->  2497 ->  2518 ->  2520 ->  2517 ->  2504 ->  2513 ->  2509 ->  2521 ->  2522 ->  2544 ->  2512 ->  2525 ->  2532 ->  2540 ->  2528 ->  2531 ->  2536 ->  2538 ->  2498 ->  2514 ->  2546 ->  996 ->  993 ->  988 ->  992 ->  4735 ->  983 ->  989 ->  994 ->  991 ->  987 ->  984 ->  986 ->  990 ->  4736 ->  985 ->  982 ->  995 ->  2360 ->  2344 ->  2345 ->  2342 ->  2356 ->  2340 ->  2351 ->  2349 ->  2354 ->  2350 ->  2347 ->  2348 ->  2346 ->  2357 ->  2355 ->  2341 ->  2343 ->  2339 ->  2352 ->  2353 ->  2338 ->  2358 ->  2362 ->  2359 ->  2361 ->  2658 ->  2663 ->  2637 ->  2641 ->  2643 ->  2649 ->  2638 ->  2642 ->  2650 ->  2636 ->  2647 ->  2648 ->  2639 ->  2640 ->  2646 ->  2651 ->  2653 ->  1790 ->  1795 ->  3919 ->  3916 ->  3917 ->  3915 ->  3911 ->  3918 ->  3914 ->  3913 ->  3908 ->  3909 ->  3910 ->  3912 ->  1791 ->  1789 ->  1774 ->  1792 ->  4898 ->  1793 ->  1773 ->  1778 ->  1779 ->  1787 ->  1783 ->  1768 ->  1769 ->  1767 ->  1786 ->  1788 ->  1785 ->  1750 ->  2665 ->  1762 ->  1780 ->  1784 ->  1761 ->  1777 ->  1781 ->  1754 ->  1776 ->  1770 ->  1742 ->  2652 ->  1766 ->  1752 ->  1737 ->  1746 ->  1782 ->  1735 ->  1740 ->  1734 ->  1763 ->  1756 ->  1755 ->  1772 ->  1747 ->  1759 ->  4896 ->  4892 ->  1745 ->  1748 ->  1749 ->  2664 ->  1726 ->  1731 ->  1744 ->  2661 ->  4899 ->  1739 ->  2656 ->  1738 ->  1753 ->  1751 ->  2666 ->  1733 ->  2657 ->  1741 ->  1771 ->  1727 ->  1743 ->  1732 ->  1729 ->  2654 ->  1757 ->  2660 ->  4901 ->  2659 ->  1764 ->  4900 ->  2662 ->  1775 ->  1765 ->  1730 ->  2655 ->  4894 ->  4891 ->  2644 ->  1728 ->  1725 ->  2645 ->  4897 ->  1758 ->  1736 ->  4895 ->  4893 ->  1760 ->  1794 ->  2402 ->  2411 ->  2413 ->  2415 ->  2397 ->  2404 ->  2405 ->  2409 ->  2403 ->  2410 ->  2399 ->  2412 ->  2401 ->  2398 ->  2407 ->  2400 ->  2416 ->  2420 ->  2419 ->  2418 ->  2406 ->  2408 ->  2414 ->  2417 ->  2421 ->  2422 ->  2739 ->  2724 ->  2730 ->  2712 ->  2721 ->  2727 ->  2703 ->  2725 ->  2731 ->  2705 ->  2711 ->  2735 ->  2717 ->  2715 ->  2701 ->  2716 ->  2704 ->  2708 ->  2728 ->  2713 ->  2707 ->  2722 ->  2702 ->  2733 ->  2710 ->  2699 ->  2726 ->  2709 ->  2719 ->  2734 ->  2729 ->  2714 ->  2700 ->  2720 ->  2718 ->  2706 ->  2723 ->  2736 ->  2732 ->  2737 ->  2740 ->  2738 ->  1394 ->  1393 ->  1397 ->  1398 ->  1400 ->  1325 ->  1326 ->  4863 ->  1360 ->  1351 ->  1365 ->  1388 ->  1334 ->  1358 ->  4862 ->  1353 ->  1386 ->  4849 ->  4846 ->  1361 ->  1368 ->  1331 ->  4859 ->  1340 ->  1363 ->  1375 ->  1332 ->  4860 ->  1346 ->  1347 ->  4851 ->  1328 ->  1338 ->  1324 ->  4852 ->  4856 ->  4850 ->  1320 ->  1357 ->  1329 ->  1377 ->  1342 ->  1384 ->  1372 ->  4848 ->  4845 ->  1330 ->  1356 ->  1336 ->  1348 ->  1333 ->  1383 ->  4854 ->  1339 ->  1387 ->  1366 ->  1382 ->  1359 ->  1373 ->  1385 ->  1322 ->  1323 ->  1370 ->  1337 ->  4861 ->  1321 ->  1354 ->  1343 ->  1335 ->  4864 ->  4853 ->  1319 ->   ...
# Distance of the route: 54486070m
#
# Maximum of the route distances: 54486070m - 54486.07km
# Objective: 54174756
# Route for vehicle 0:
#  3433 ->  3430 ->  3434 ->  3419 ->  3432 ->  3429 ->  3420 ->  3424 ->  3416 ->  3425 ->  3428 ->  3427 ->  3423 ->  3417 ->  3421 ->  3426 ->  3431 ->  3422 ->  3418 ->  3435 ->  3436 ->  3437 ->  4077 ->  4076 ->  4072 ->  4073 ->  4075 ->  4074 ->  4078 ->  2337 ->  2327 ->  2312 ->  2318 ->  2309 ->  2317 ->  2333 ->  2335 ->  2336 ->  2326 ->  2328 ->  2320 ->  2308 ->  2313 ->  2311 ->  2321 ->  2310 ->  2332 ->  2325 ->  2331 ->  2314 ->  2334 ->  2316 ->  2324 ->  2329 ->  2319 ->  2330 ->  2322 ->  2323 ->  2315 ->  1865 ->  1853 ->  1864 ->  4885 ->  1854 ->  1858 ->  1866 ->  1850 ->  1857 ->  1859 ->  4882 ->  4886 ->  1861 ->  1863 ->  1855 ->  1867 ->  1862 ->  1860 ->  4884 ->  1852 ->  1856 ->  1851 ->  4883 ->  1868 ->  1869 ->  1870 ->  1871 ->  1873 ->  2269 ->  1872 ->  2545 ->  2530 ->  2511 ->  2519 ->  2506 ->  2535 ->  2537 ->  2515 ->  2523 ->  2502 ->  2543 ->  2539 ->  2524 ->  2510 ->  2526 ->  2533 ->  2508 ->  2534 ->  2527 ->  2499 ->  2501 ->  2500 ->  2507 ->  2516 ->  2541 ->  2542 ->  2505 ->  2529 ->  2503 ->  2497 ->  2518 ->  2520 ->  2517 ->  2504 ->  2513 ->  2509 ->  2521 ->  2522 ->  2544 ->  2512 ->  2525 ->  2532 ->  2540 ->  2528 ->  2531 ->  2536 ->  2538 ->  2498 ->  2514 ->  2546 ->  996 ->  993 ->  988 ->  992 ->  4735 ->  983 ->  989 ->  994 ->  991 ->  987 ->  984 ->  986 ->  990 ->  4736 ->  985 ->  982 ->  995 ->  2360 ->  2344 ->  2345 ->  2342 ->  2356 ->  2340 ->  2351 ->  2349 ->  2354 ->  2350 ->  2347 ->  2348 ->  2346 ->  2357 ->  2355 ->  2341 ->  2343 ->  2339 ->  2352 ->  2353 ->  2338 ->  2358 ->  2362 ->  2359 ->  2361 ->  2658 ->  2663 ->  2637 ->  2641 ->  2643 ->  2649 ->  2638 ->  2642 ->  2650 ->  2636 ->  2647 ->  2648 ->  2639 ->  2640 ->  2646 ->  2651 ->  2653 ->  1790 ->  1795 ->  3919 ->  3916 ->  3917 ->  3915 ->  3911 ->  3918 ->  3914 ->  3913 ->  3908 ->  3909 ->  3910 ->  3912 ->  1791 ->  1789 ->  1774 ->  1792 ->  4898 ->  1793 ->  1773 ->  1778 ->  1779 ->  1787 ->  1783 ->  1768 ->  1769 ->  1767 ->  1786 ->  1788 ->  1785 ->  1750 ->  2665 ->  1762 ->  1780 ->  1784 ->  1761 ->  1777 ->  1781 ->  1754 ->  1776 ->  1770 ->  1742 ->  2652 ->  1766 ->  1752 ->  1737 ->  1746 ->  1782 ->  1735 ->  1740 ->  1734 ->  1763 ->  1756 ->  1755 ->  1772 ->  1747 ->  1759 ->  4896 ->  4892 ->  1745 ->  1748 ->  1749 ->  2664 ->  1726 ->  1731 ->  1744 ->  2661 ->  4899 ->  1739 ->  2656 ->  1738 ->  1753 ->  1751 ->  2666 ->  1733 ->  2657 ->  1741 ->  1771 ->  1727 ->  1743 ->  1732 ->  1729 ->  2654 ->  1757 ->  2660 ->  4901 ->  2659 ->  1764 ->  4900 ->  2662 ->  1775 ->  1765 ->  1730 ->  2655 ->  4894 ->  1725 ->  4891 ->  2644 ->  1728 ->  2645 ->  4897 ->  1758 ->  1736 ->  4895 ->  4893 ->  1760 ->  1794 ->  2402 ->  2411 ->  2413 ->  2415 ->  2397 ->  2404 ->  2405 ->  2409 ->  2403 ->  2410 ->  2399 ->  2412 ->  2401 ->  2398 ->  2407 ->  2400 ->  2416 ->  2420 ->  2419 ->  2418 ->  2406 ->  2408 ->  2414 ->  2417 ->  2421 ->  2422 ->  2739 ->  2706 ->  2718 ->  2714 ->  2729 ->  2724 ->  2730 ->  2712 ->  2721 ->  2727 ->  2703 ->  2725 ->  2731 ->  2705 ->  2711 ->  2735 ->  2717 ->  2715 ->  2701 ->  2716 ->  2704 ->  2708 ->  2728 ->  2713 ->  2707 ->  2722 ->  2702 ->  2733 ->  2710 ->  2699 ->  2726 ->  2709 ->  2719 ->  2734 ->  2700 ->  2720 ->  2723 ->  2736 ->  2732 ->  2737 ->  2740 ->  2738 ->  1394 ->  1393 ->  1397 ->  1398 ->  1400 ->  1365 ->  1351 ->  1388 ->  1334 ->  1358 ->  4862 ->  1353 ->  1386 ->  1340 ->  1363 ->  1375 ->  1332 ->  4860 ->  1346 ->  1347 ->  4851 ->  1328 ->  1338 ->  1324 ->  4852 ->  4856 ->  4850 ->  1320 ->  1357 ->  1329 ->  1377 ->  1342 ->  1384 ->  1372 ->  4848 ->  1371 ->  1327 ->  1367 ->  1319 ->  4853 ->  4864 ->  1335 ->  1343 ->  4845 ->  1330 ->  1356 ->  1336 ->  1348 ->  1333 ->  1383 ->  4854 ->  1339 ->  1387 ->  1366 ->  1382 ->  1359 ->  1373 ->  1385 ->  1322 ->  1323 ->  1370 ->  1337 ->  4861 ->  1321 ->  1354 ->  1331 ->  4859 ->  4849 ->  4846 ->  1361 ->  1368 ->  1360 ->   ...
# Distance of the route: 54174756m
#
# Maximum of the route distances: 54174756m - 54174.756km

# %%
# Граф маршрута
solver_graph = create_graph_after_solver(G, routes)

# Визуализация графа
create_map_from_graph(solver_graph)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Определение оптимального количества кластеров
search_KMedoids(G, 40, 60)

# %%
# Кластеризованный граф и медоиды каждого кластера
work_graph, medoids = kmedoids_clustering_for_graph(G, 40)

# %%
# Выделение графа по медоидам
med_graph = G.subgraph(medoids)

# Визуализация графа из медоид каждого кластера
# create_map_from_graph(med_graph)

# %%
# TODO: Сохранять наикратчайший маршрут, а не последний посчитанный
cluster_routes, b = search_optimal_path(med_graph, clusters=True, timeout=30)
# Out:
# Objective: 26934326
# Route for vehicle 0:
#  40 ->  15 ->  27 ->  65 ->  34 ->  46 ->  1 ->  28 ->  32 ->  36 ->  50 ->  56 ->  24 ->  69 ->  4 ->  6 ->  16 ->  44 ->  67 ->  43 ->  31 ->  63 ->  33 ->  7 ->  17 ->  54 ->  61 ->  51 ->  3 ->  25 ->  12 ->  18 ->  60 ->  55 ->  8 ->  47 ->  10 ->  58 ->  66 ->  35 ->  13 ->  14 ->  5 ->  42 ->  2 ->  30 ->  59 ->  68 ->  53 ->  21 ->  29 ->  37 ->  64 ->  41 ->  39 ->  0 ->  19 ->  62 ->  26 ->  20 ->  23 ->  52 ->  11 ->  45 ->  22 ->  38 ->  49 ->  9 ->  57 -> 48
# Distance of the route: 26934326m
#
# Maximum of the route distances: 26934326m - 26934.326km
# Objective: 26376714
# Route for vehicle 0:
#  40 ->  15 ->  65 ->  27 ->  50 ->  34 ->  46 ->  1 ->  28 ->  32 ->  36 ->  8 ->  55 ->  47 ->  60 ->  18 ->  12 ->  25 ->  3 ->  54 ->  17 ->  61 ->  51 ->  6 ->  4 ->  69 ->  24 ->  56 ->  16 ->  44 ->  67 ->  43 ->  31 ->  63 ->  33 ->  7 ->  35 ->  66 ->  13 ->  58 ->  10 ->  14 ->  5 ->  42 ->  2 ->  30 ->  59 ->  21 ->  53 ->  68 ->  37 ->  64 ->  29 ->  41 ->  39 ->  0 ->  19 ->  62 ->  26 ->  20 ->  23 ->  52 ->  11 ->  45 ->  22 ->  38 ->  49 ->  9 ->  57 -> 48
# Distance of the route: 26376714m
#
# Maximum of the route distances: 26376714m - 26376.714km

# %%
# TODO: сделать это частью функции.
# переход индексов матрицы от 0 до N в индексы графа
d = {}
correct_clusters = []
correct_nodes = []
for i, node in enumerate(med_graph.nodes(data=True), 0):
    d[i] = (node[0], node[1]['cluster_number']) # {index: (номер ноды, номер кластера)}
for i in cluster_routes:
    # перебирая словарь, выделяем список кластеров по порядку и нод по порядку.
    # Кластеры нужны, чтобы по ним проходиться i и i+1
    # Ноды нужны для функции create_graph_after_solver, чтобы выделить последовательность пути
    correct_nodes.append(d[i][0])
    correct_clusters.append(d[i][1])

# %%
test = create_graph_after_solver(med_graph, correct_nodes)

# %%
# Визуализация графа
create_map_from_graph(test)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a4bc81262ca5a63f336e79ec8dc03a06 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a4bc81262ca5a63f336e79ec8dc03a06&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a4bc81262ca5a63f336e79ec8dc03a06 = L.map(
#                 &quot;map_a4bc81262ca5a63f336e79ec8dc03a06&quot;,
#                 {
#                     center: [56.322, 90.004],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07c4dfe45043f22d33d6292f3aa30553 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a4bc81262ca5a63f336e79ec8dc03a06);
#
#
#             var circle_marker_8118b5e8b828f3965d5a130d47636db7 = L.circleMarker(
#                 [44.755124, 33.850233],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a4bc81262ca5a63f336e79ec8dc03a06);
#
#
#             var circle_marker_5984c71f33ba4d150390fc99561a6fb9 = L.circleMarker(
#                 [44.694117, 37.788162],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a4bc81262ca5a63f336e79ec8dc03a06);
#
#
#             var circle_marker_75d2cc7882ec03a9a3eb75c3eb8e2f99 = L.circleMarker(
#                 [43.590057, 39.733213],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a4bc81262ca5a63f336e79ec8dc03a06);
#
#
#             var circle_marker_c84a4f1c628c88d59ea13d1f8b97d451 = L.circleMarker(
#                 [45.048595, 38.984718],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a4bc81262ca5a63f336e79ec8dc03a06);
#
#
#             var circle_marker_899b257a8b7a5ac4a542e2c9c2985fca = L.circleMarker(
#                 [47.248939, 39.728934],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a4bc81262ca5a63f336e79ec8dc03a06);
#
#
#             var circle_marker_845e3ac9476e64279c97e8a0814cf5c4 = L.circleMarker(
#                 [45.021276, 41.890705],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a4bc81262ca5a63f336e79ec8dc03a06);
#
#
#             var circle_marker_3d02b0a47bf13d6ad3d76b03d5f2279d = L.circleMarker(
#                 [44.

# %%
for i in correct_clusters:
    print(i, end=' ')
# Out:
# 34 19 29 3 4 5 13 0 27 21 22 20 30 35 9 31 37 28 6 39 15 7 17 25 23 18 12 36 10 32 24 14 8 11 16 2 38 26 33 1

# %%
transition, extreme_points = search_min_weight_path(work_graph, correct_clusters)

# %%
transition

# %%
extreme_points[0]
# Out:
# [327, 37]

# %%
def create_graph_after_solver_full(graph, full_graph, routes):
    for node in routes:
        # Копирование атрибутов узла из оригинального графа G в новый граф new_G
        if node in graph.nodes():
            full_graph.add_node(node, **graph.nodes[node])
    for i in range(len(routes) - 1):
        node1 = routes[i]
        node2 = routes[i + 1]
        if graph.has_edge(node1, node2):
            # Копирование атрибутов ребра из оригинального графа G в новый граф new_G
            full_graph.add_edge(node1, node2, **graph.get_edge_data(node1, node2))
        # else:
        #     new_G.add_edge(node1, node2, weight=40000000)
    return full_graph

# %%
work_graph.get_edge_data(i[0], i[1])['weight']
# Out:
# 397050

# %%
full_graph = nx.Graph()
full_path = 0
for i in tqdm(correct_clusters):
    selected_nodes = [node for node, attr in work_graph.nodes(data=True) if attr['cluster_number'] == correct_clusters[i]]
    sub = work_graph.subgraph(selected_nodes).copy()
    cluster_routes_sub, path = search_optimal_path(sub, clusters=True, timeout=60, extreme=extreme_points[i])
    full_path += path
    # input()
    d_sub = {}
    correct_clusters_sub = []
    correct_nodes_sub = []
    for i, node in enumerate(sub.nodes(data=True), 0):
        d_sub[i] = (node[0], node[1]['cluster_number']) # {index: (номер ноды, номер кластера)}

    for i in cluster_routes_sub:
        # перебирая словарь, выделяем список кластеров по порядку и нод по порядку.
        # Кластеры нужны, чтобы по ним проходиться i и i+1
        # Ноды нужны для функции create_graph_after_solver, чтобы выделить последовательность пути
        correct_nodes_sub.append(d_sub[i][0])
        correct_clusters_sub.append(d_sub[i][1])
    full_graph = create_graph_after_solver_full(sub, full_graph, correct_nodes_sub)
print(full_path)
for i in transition.values():
    if work_graph.has_edge(i[0], i[1]):
        full_path += work_graph.get_edge_data(i[0], i[1])['weight']
        # Копирование атрибутов ребра из оригинального графа G в новый граф new_G
        full_graph.add_edge(i[0], i[1], **work_graph.get_edge_data(i[0], i[1]))
print(f'{full_path}m - {full_path/1000}km')
print(f"{full_path - work_graph.get_edge_data(944, 541)['weight']}m - {(full_path - work_graph.get_edge_data(944, 541)['weight'])/1000}km")
# Out:
# Objective: 758015
# Route for vehicle 0:
#  23 ->  1 ->  36 ->  24 ->  21 ->  26 ->  28 ->  22 ->  25 ->  9 ->  7 ->  29 ->  6 ->  8 ->  31 ->  19 ->  12 ->  4 ->  10 ->  0 ->  16 ->  5 ->  13 ->  35 ->  11 ->  17 ->  20 ->  15 ->  30 ->  2 ->  3 ->  14 ->  18 ->  27 ->  37 ->  32 ->  33 -> 34
# Distance of the route: 758015m
#
# Maximum of the route distances: 758015m - 758.015km
# Objective: 761668
# Route for vehicle 0:
#  23 ->  1 ->  36 ->  24 ->  21 ->  26 ->  28 ->  22 ->  25 ->  11 ->  35 ->  13 ->  5 ->  16 ->  0 ->  9 ->  7 ->  29 ->  6 ->  8 ->  31 ->  19 ->  12 ->  14 ->  3 ->  2 ->  4 ->  10 ->  30 ->  15 ->  17 ->  20 ->  18 ->  27 ->  37 ->  32 ->  33 -> 34
# Distance of the route: 761668m
#
# Maximum of the route distances: 761668m - 761.668km
# Objective: 153502
# Route for vehicle 0:
#  90 ->  124 ->  62 ->  44 ->  115 ->  112 ->  74 ->  71 ->  104 ->  107 ->  46 ->  103 ->  19 ->  89 ->  96 ->  60 ->  92 ->  28 ->  23 ->  105 ->  100 ->  118 ->  56 ->  80 ->  111 ->  75 ->  38 ->  81 ->  53 ->  59 ->  55 ->  5 ->  84 ->  106 ->  31 ->  76 ->  43 ->  33 ->  94 ->  122 ->  117 ->  119 ->  82 ->  45 ->  24 ->  34 ->  116 ->  110 ->  29 ->  69 ->  54 ->  121 ->  49 ->  47 ->  22 ->  52 ->  30 ->  8 ->  64 ->  58 ->  13 ->  1 ->  3 ->  26 ->  70 ->  4 ->  27 ->  12 ->  9 ->  14 ->  37 ->  6 ->  40 ->  50 ->  101 ->  63 ->  123 ->  97 ->  36 ->  42 ->  83 ->  78 ->  65 ->  120 ->  72 ->  25 ->  88 ->  0 ->  15 ->  98 ->  57 ->  51 ->  35 ->  16 ->  10 ->  87 ->  108 ->  18 ->  85 ->  41 ->  39 ->  48 ->  66 ->  2 ->  68 ->  20 ->  11 ->  61 ->  114 ->  17 ->  21 ->  73 ->  67 ->  113 ->  7 ->  109 ->  79 ->  32 ->  102 ->  86 ->  93 ->  99 ->  91 ->  77 -> 95
# Distance of the route: 153502m
#
# Maximum of the route distances: 153502m - 153.502km
# Objective: 151471
# Route for vehicle 0:
#  90 ->  124 ->  62 ->  44 ->  115 ->  112 ->  74 ->  71 ->  104 ->  107 ->  46 ->  103 ->  19 ->  89 ->  96 ->  60 ->  92 ->  28 ->  23 ->  105 ->  100 ->  118 ->  56 ->  80 ->  78 ->  65 ->  83 ->  42 ->  120 ->  72 ->  36 ->  97 ->  101 ->  63 ->  123 ->  111 ->  75 ->  38 ->  81 ->  53 ->  59 ->  55 ->  5 ->  84 ->  106 ->  58 ->  8 ->  30 ->  52 ->  64 ->  13 ->  1 ->  3 ->  26 ->  70 ->  4 ->  27 ->  12 ->  9 ->  14 ->  37 ->  6 ->  40 ->  50 ->  25 ->  88 ->  0 ->  15 ->  98 ->  57 ->  51 ->  35 ->  16 ->  10 ->  87 ->  108 ->  18 ->  85 ->  41 ->  39 ->  48 ->  66 ->  2 ->  68 ->  110 ->  29 ->  69 ->  54 ->  121 ->  49 ->  47 ->  22 ->  119 ->  33 ->  31 ->  76 ->  43 ->  94 ->  117 ->  122 ->  82 ->  24 ->  34 ->  116 ->  20 ->  11 ->  61 ->  114 ->  17 ->  21 ->  73 ->  67 ->  7 ->  109 ->  113 ->  32 ->  102 ->  86 ->  93 ->  99 ->  91 ->  77 ->  79 ->  45 -> 95
# Distance of the route: 151471m
#
# Maximum of the route distances: 151471m - 151.471km
# Objective: 534032
# Route for vehicle 0:
#  40 ->  39 ->  38 ->  23 ->  30 ->  19 ->  5 ->  32 ->  24 ->  13 ->  4 ->  37 ->  33 ->  0 ->  36 ->  1 ->  21 ->  35 ->  25 ->  26 ->  17 ->  34 ->  16 ->  12 ->  7 ->  14 ->  11 ->  8 ->  6 ->  20 ->  2 ->  15 ->  18 ->  9 ->  31 ->  28 ->  3 ->  83 ->  10 ->  22 ->  29 ->  27 ->  79 ->  80 ->  48 ->  45 ->  47 ->  44 ->  46 ->  77 ->  70 ->  78 ->  75 ->  76 ->  43 ->  61 ->  81 ->  82 ->  62 ->  65 ->  64 ->  74 ->  73 ->  58 ->  60 ->  59 ->  57 ->  56 ->  41 ->  53 ->  51 ->  55 ->  50 ->  49 ->  42 ->  54 ->  52 ->  69 ->  66 ->  71 ->  63 ->  67 ->  72 -> 68
# Distance of the route: 534032m
#
# Maximum of the route distances: 534032m - 534.032km
# Objective: 523397
# Route for vehicle 0:
#  40 ->  39 ->  38 ->  23 ->  30 ->  19 ->  5 ->  32 ->  24 ->  13 ->  4 ->  37 ->  33 ->  0 ->  36 ->  1 ->  21 ->  35 ->  25 ->  26 ->  17 ->  34 ->  16 ->  12 ->  7 ->  14 ->  11 ->  8 ->  6 ->  20 ->  2 ->  15 ->  18 ->  9 ->  31 ->  28 ->  3 ->  83 ->  10 ->  22 ->  29 ->  27 ->  79 ->  80 ->  48 ->  45 ->  47 ->  44 ->  46 ->  77 ->  70 ->  52 ->  54 ->  42 ->  49 ->  50 ->  55 ->  51 ->  53 ->  41 ->  56 ->  57 ->  59 ->  60 ->  58 ->  78 ->  75 ->  76 ->  43 ->  61 ->  81 ->  82 ->  62 ->  65 ->  64 ->  74 ->  73 ->  69 ->  66 ->  71 ->  63 ->  67 ->  72 -> 68
# Distance of the route: 523397m
#
# Maximum of the route distances: 523397m - 523.397km
# Objective: 277764
# Route for vehicle 0:
#  35 ->  15 ->  34 ->  28 ->  0 ->  44 ->  50 ->  6 ->  45 ->  43 ->  5 ->  17 ->  53 ->  67 ->  68 ->  22 ->  51 ->  54 ->  46 ->  21 ->  2 ->  38 ->  49 ->  30 ->  37 ->  7 ->  29 ->  16 ->  13 ->  27 ->  10 ->  64 ->  24 ->  39 ->  59 ->  25 ->  63 ->  36 ->  23 ->  8 ->  18 ->  12 ->  56 ->  1 ->  57 ->  40 ->  62 ->  61 ->  60 ->  47 ->  55 ->  42 ->  66 ->  65 ->  41 ->  31 ->  32 ->  3 ->  20 ->  48 ->  11 ->  69 ->  33 ->  19 ->  52 ->  26 ->  9 ->  14 ->  4 -> 58
# Distance of the route: 277764m
#
# Maximum of the route distances: 277764m - 277.764km
# Objective: 278993
# Route for vehicle 0:
#  35 ->  15 ->  34 ->  28 ->  6 ->  0 ->  44 ->  50 ->  51 ->  22 ->  68 ->  67 ->  43 ->  45 ->  5 ->  17 ->  53 ->  46 ->  21 ->  2 ->  38 ->  49 ->  54 ->  30 ->  37 ->  7 ->  29 ->  16 ->  13 ->  27 ->  10 ->  64 ->  24 ->  39 ->  59 ->  56 ->  12 ->  1 ->  61 ->  62 ->  40 ->  57 ->  18 ->  8 ->  23 ->  36 ->  25 ->  63 ->  60 ->  47 ->  55 ->  42 ->  66 ->  65 ->  41 ->  31 ->  32 ->  3 ->  20 ->  48 ->  11 ->  69 ->  33 ->  19 ->  52 ->  26 ->  9 ->  14 ->  4 -> 58
# Distance of the route: 278993m
#
# Maximum of the route distances: 278993m - 278.993km
# Objective: 80218
# Route for vehicle 0:
#  9 ->  19 ->  3 ->  8 ->  12 ->  14 ->  5 ->  21 ->  13 ->  0 ->  4 ->  16 ->  18 ->  10 ->  22 ->  17 ->  15 ->  2 ->  7 ->  11 ->  6 ->  1 ->  20 ->  23 -> 24
# Distance of the route: 80218m
#
# Maximum of the route distances: 80218m - 80.218km
# Objective: 80218
# Route for vehicle 0:
#  9 ->  19 ->  3 ->  8 ->  12 ->  14 ->  5 ->  21 ->  13 ->  0 ->  4 ->  16 ->  18 ->  10 ->  22 ->  17 ->  15 ->  2 ->  7 ->  11 ->  6 ->  1 ->  20 ->  23 -> 24
# Distance of the route: 80218m
#
# Maximum of the route distances: 80218m - 80.218km
# Objective: 81832
# Route for vehicle 0:
#  5 ->  4 ->  0 ->  1 ->  3 ->  2 -> 6
# Distance of the route: 81832m
#
# Maximum of the route distances: 81832m - 81.832km
# Objective: 81832
# Route for vehicle 0:
#  5 ->  4 ->  0 ->  1 ->  3 ->  2 -> 6
# Distance of the route: 81832m
#
# Maximum of the route distances: 81832m - 81.832km
# Objective: 297248
# Route for vehicle 0:
#  8 ->  6 ->  4 ->  7 ->  13 ->  0 ->  1 ->  9 ->  3 ->  2 ->  5 ->  12 ->  11 ->  10 ->  14 ->  19 ->  15 ->  18 ->  17 ->  16 -> 20
# Distance of the route: 297248m
#
# Maximum of the route distances: 297248m - 297.248km
# Objective: 297248
# Route for vehicle 0:
#  8 ->  6 ->  4 ->  7 ->  13 ->  0 ->  1 ->  9 ->  3 ->  2 ->  5 ->  12 ->  11 ->  10 ->  14 ->  19 ->  15 ->  18 ->  17 ->  16 -> 20
# Distance of the route: 297248m
#
# Maximum of the route distances: 297248m - 297.248km
# Objective: 282091
# Route for vehicle 0:
#  64 ->  72 ->  80 ->  74 ->  47 ->  75 ->  63 ->  69 ->  35 ->  53 ->  45 ->  40 ->  44 ->  57 ->  60 ->  38 ->  14 ->  21 ->  29 ->  17 ->  56 ->  27 ->  30 ->  24 ->  50 ->  32 ->  5 ->  20 ->  58 ->  36 ->  42 ->  62 ->  41 ->  31 ->  51 ->  52 ->  13 ->  18 ->  37 ->  59 ->  8 ->  39 ->  22 ->  23 ->  0 ->  1 ->  46 ->  12 ->  9 ->  4 ->  61 ->  7 ->  26 ->  6 ->  11 ->  15 ->  16 ->  54 ->  25 ->  19 ->  10 ->  28 ->  48 ->  33 ->  3 ->  49 ->  65 ->  67 ->  66 ->  34 ->  73 ->  55 ->  77 ->  43 ->  2 ->  71 ->  68 ->  78 ->  70 ->  82 ->  79 ->  81 -> 76
# Distance of the route: 282091m
#
# Maximum of the route distances: 282091m - 282.091km
# Objective: 286455
# Route for vehicle 0:
#  64 ->  72 ->  80 ->  74 ->  47 ->  75 ->  63 ->  69 ->  35 ->  53 ->  45 ->  54 ->  19 ->  25 ->  3 ->  33 ->  48 ->  28 ->  10 ->  16 ->  15 ->  40 ->  44 ->  57 ->  60 ->  38 ->  14 ->  21 ->  29 ->  17 ->  56 ->  27 ->  30 ->  24 ->  50 ->  32 ->  5 ->  20 ->  36 ->  58 ->  52 ->  39 ->  22 ->  23 ->  0 ->  1 ->  46 ->  12 ->  9 ->  4 ->  11 ->  6 ->  26 ->  7 ->  61 ->  8 ->  59 ->  37 ->  18 ->  13 ->  51 ->  42 ->  62 ->  41 ->  31 ->  49 ->  65 ->  67 ->  66 ->  34 ->  73 ->  55 ->  77 ->  43 ->  2 ->  71 ->  68 ->  78 ->  70 ->  82 ->  79 ->  81 -> 76
# Distance of the route: 286455m
#
# Maximum of the route distances: 286455m - 286.455km
# Objective: 842201
# Route for vehicle 0:
#  114 ->  62 ->  104 ->  107 ->  77 ->  88 ->  132 ->  156 ->  146 ->  155 ->  154 ->  141 ->  145 ->  134 ->  144 ->  153 ->  152 ->  135 ->  151 ->  150 ->  148 ->  139 ->  138 ->  149 ->  157 ->  140 ->  79 ->  147 ->  143 ->  142 ->  136 ->  130 ->  131 ->  109 ->  128 ->  129 ->  124 ->  55 ->  110 ->  86 ->  48 ->  68 ->  188 ->  60 ->  76 ->  18 ->  97 ->  169 ->  32 ->  43 ->  78 ->  182 ->  161 ->  25 ->  31 ->  2 ->  178 ->  63 ->  119 ->  113 ->  66 ->  121 ->  20 ->  85 ->  99 ->  12 ->  174 ->  70 ->  159 ->  74 ->  69 ->  22 ->  8 ->  56 ->  181 ->  3 ->  183 ->  172 ->  0 ->  108 ->  84 ->  50 ->  93 ->  89 ->  42 ->  45 ->  185 ->  98 ->  160 ->  21 ->  26 ->  75 ->  67 ->  176 ->  116 ->  164 ->  87 ->  120 ->  180 ->  53 ->  40 ->  65 ->  30 ->  80 ->  4 ->  95 ->  24 ->  166 ->  177 ->  158 ->  36 ->  19 ->  102 ->  58 ->  106 ->  13 ->  179 ->  61 ->  101 ->  122 ->  54 ->  162 ->  46 ->  127 ->  126 ->  64 ->  44 ->  5 ->  41 ->  27 ->  29 ->  49 ->  14 ->  111 ->  117 ->  1 ->  96 ->  175 ->  47 ->  112 ->  137 ->  39 ->  9 ->  91 ->  171 ->  168 ->  123 ->  10 ->  16 ->  51 ->  35 ->  173 ->  92 ->  83 ->  170 ->  28 ->  17 ->  167 ->  7 ->  165 ->  11 ->  163 ->  23 ->  15 ->  37 ->  94 ->  34 ->  115 ->  100 ->  6 ->  59 ->  133 ->  81 ->  105 ->  33 ->  125 ->  52 ->  82 ->  118 ->  72 ->  90 ->  38 ->  103 ->  57 ->  71 ->  73 ->  187 ->  186 -> 184
# Distance of the route: 842201m
#
# Maximum of the route distances: 842201m - 842.201km
# Objective: 841571
# Route for vehicle 0:
#  114 ->  77 ->  88 ->  107 ->  62 ->  104 ->  146 ->  156 ->  132 ->  155 ->  154 ->  141 ->  145 ->  134 ->  144 ->  153 ->  152 ->  135 ->  151 ->  150 ->  148 ->  139 ->  138 ->  149 ->  157 ->  140 ->  79 ->  147 ->  143 ->  142 ->  136 ->  130 ->  131 ->  109 ->  128 ->  129 ->  124 ->  55 ->  110 ->  86 ->  18 ->  76 ->  60 ->  188 ->  68 ->  48 ->  30 ->  65 ->  53 ->  40 ->  80 ->  4 ->  95 ->  24 ->  166 ->  177 ->  158 ->  36 ->  19 ->  102 ->  58 ->  106 ->  21 ->  26 ->  75 ->  67 ->  176 ->  116 ->  164 ->  87 ->  120 ->  180 ->  69 ->  74 ->  159 ->  70 ->  32 ->  97 ->  169 ->  43 ->  78 ->  182 ->  161 ->  25 ->  31 ->  2 ->  178 ->  63 ->  119 ->  99 ->  85 ->  20 ->  113 ->  66 ->  121 ->  6 ->  59 ->  133 ->  81 ->  105 ->  33 ->  125 ->  100 ->  115 ->  34 ->  94 ->  37 ->  15 ->  23 ->  163 ->  11 ->  165 ->  91 ->  9 ->  39 ->  137 ->  112 ->  175 ->  47 ->  185 ->  42 ->  89 ->  108 ->  84 ->  170 ->  83 ->  92 ->  173 ->  50 ->  93 ->  35 ->  51 ->  16 ->  10 ->  123 ->  168 ->  171 ->  7 ->  167 ->  28 ->  17 ->  174 ->  12 ->  56 ->  181 ->  8 ->  22 ->  3 ->  183 ->  172 ->  0 ->  45 ->  98 ->  160 ->  13 ->  179 ->  61 ->  101 ->  122 ->  54 ->  162 ->  46 ->  127 ->  126 ->  64 ->  44 ->  38 ->  5 ->  41 ->  90 ->  27 ->  29 ->  49 ->  14 ->  111 ->  117 ->  1 ->  96 ->  52 ->  82 ->  118 ->  72 ->  103 ->  57 ->  71 ->  73 ->  187 ->  186 -> 184
# Distance of the route: 841571m
#
# Maximum of the route distances: 841571m - 841.571km
# Objective: 89780
# Route for vehicle 0:
#  3 ->  7 ->  10 ->  5 ->  15 ->  11 ->  9 ->  12 ->  16 ->  2 ->  14 ->  6 ->  8 ->  0 ->  13 ->  1 -> 4
# Distance of the route: 89780m
#
# Maximum of the route distances: 89780m - 89.78km
# Objective: 89780
# Route for vehicle 0:
#  3 ->  7 ->  10 ->  5 ->  15 ->  11 ->  9 ->  12 ->  16 ->  2 ->  14 ->  6 ->  8 ->  0 ->  13 ->  1 -> 4
# Distance of the route: 89780m
#
# Maximum of the route distances: 89780m - 89.78km
# Objective: 962751
# Route for vehicle 0:
#  132 ->  131 ->  126 ->  129 ->  127 ->  128 ->  125 ->  130 ->  133 ->  104 ->  111 ->  101 ->  100 ->  92 ->  95 ->  93 ->  89 ->  91 ->  34 ->  46 ->  51 ->  64 ->  110 ->  141 ->  116 ->  115 ->  114 ->  145 ->  97 ->  138 ->  140 ->  135 ->  134 ->  139 ->  137 ->  113 ->  136 ->  143 ->  142 ->  144 ->  105 ->  109 ->  103 ->  150 ->  146 ->  108 ->  96 ->  107 ->  151 ->  148 ->  149 ->  152 ->  118 ->  106 ->  102 ->  147 ->  99 ->  94 ->  153 ->  98 ->  73 ->  49 ->  43 ->  32 ->  68 ->  18 ->  31 ->  90 ->  30 ->  38 ->  55 ->  26 ->  70 ->  54 ->  20 ->  53 ->  78 ->  16 ->  50 ->  71 ->  22 ->  11 ->  2 ->  3 ->  23 ->  37 ->  117 ->  13 ->  56 ->  86 ->  84 ->  66 ->  88 ->  69 ->  36 ->  76 ->  82 ->  79 ->  67 ->  81 ->  35 ->  15 ->  47 ->  52 ->  61 ->  45 ->  4 ->  0 ->  87 ->  24 ->  44 ->  41 ->  123 ->  5 ->  1 ->  12 ->  10 ->  60 ->  85 ->  80 ->  122 ->  58 ->  65 ->  7 ->  83 ->  27 ->  40 ->  63 ->  25 ->  48 ->  72 ->  28 ->  9 ->  120 ->  57 ->  42 ->  77 ->  29 ->  17 ->  21 ->  59 ->  124 ->  119 ->  8 ->  6 ->  39 ->  75 ->  121 ->  19 ->  14 ->  33 ->  74 ->  62 ->  112 ->  166 ->  161 ->  156 ->  160 ->  164 ->  158 ->  159 ->  157 ->  163 ->  155 ->  154 ->  165 -> 162
# Distance of the route: 962751m
#
# Maximum of the route distances: 962751m - 962.751km
# Objective: 956708
# Route for vehicle 0:
#  132 ->  129 ->  126 ->  127 ->  128 ->  125 ->  130 ->  131 ->  116 ->  115 ->  114 ->  145 ->  97 ->  141 ->  138 ->  140 ->  135 ->  134 ->  139 ->  137 ->  113 ->  136 ->  143 ->  142 ->  144 ->  105 ->  109 ->  103 ->  99 ->  94 ->  147 ->  102 ->  150 ->  146 ->  108 ->  96 ->  107 ->  106 ->  118 ->  152 ->  153 ->  98 ->  149 ->  151 ->  148 ->  110 ->  133 ->  104 ->  111 ->  64 ->  51 ->  34 ->  91 ->  89 ->  46 ->  80 ->  122 ->  58 ->  85 ->  60 ->  10 ->  12 ->  1 ->  5 ->  123 ->  41 ->  44 ->  24 ->  87 ->  0 ->  4 ->  45 ->  61 ->  52 ->  47 ->  71 ->  16 ->  20 ->  78 ->  53 ->  50 ->  11 ->  2 ->  22 ->  15 ->  35 ->  3 ->  23 ->  37 ->  117 ->  56 ->  13 ->  54 ->  70 ->  26 ->  55 ->  38 ->  30 ->  90 ->  31 ->  32 ->  18 ->  68 ->  73 ->  49 ->  43 ->  79 ->  82 ->  76 ->  67 ->  36 ->  69 ->  88 ->  66 ->  84 ->  86 ->  81 ->  17 ->  29 ->  77 ->  42 ->  57 ->  21 ->  59 ->  124 ->  119 ->  8 ->  6 ->  39 ->  75 ->  121 ->  19 ->  14 ->  33 ->  120 ->  63 ->  40 ->  65 ->  7 ->  83 ->  27 ->  25 ->  48 ->  72 ->  9 ->  28 ->  74 ->  62 ->  93 ->  95 ->  101 ->  100 ->  92 ->  112 ->  166 ->  161 ->  156 ->  160 ->  164 ->  158 ->  159 ->  157 ->  163 ->  155 ->  154 ->  165 -> 162
# Distance of the route: 956708m
#
# Maximum of the route distances: 956708m - 956.708km
# Objective: 694006
# Route for vehicle 0:
#  16 ->  14 ->  8 ->  9 ->  5 ->  1 ->  18 ->  4 ->  2 ->  11 ->  0 ->  6 ->  17 ->  10 ->  13 ->  12 ->  3 ->  7 ->  15 ->  45 ->  42 ->  41 ->  43 ->  44 ->  38 ->  37 ->  35 ->  30 ->  32 ->  29 ->  33 ->  24 ->  21 ->  25 ->  28 ->  31 ->  22 ->  36 ->  26 ->  23 ->  34 ->  27 ->  19 ->  39 ->  20 -> 40
# Distance of the route: 694006m
#
# Maximum of the route distances: 694006m - 694.006km
# Objective: 694006
# Route for vehicle 0:
#  16 ->  14 ->  8 ->  9 ->  5 ->  1 ->  18 ->  4 ->  2 ->  11 ->  0 ->  6 ->  17 ->  10 ->  13 ->  12 ->  3 ->  7 ->  15 ->  45 ->  42 ->  41 ->  43 ->  44 ->  38 ->  37 ->  35 ->  30 ->  32 ->  29 ->  33 ->  24 ->  21 ->  25 ->  28 ->  31 ->  22 ->  36 ->  26 ->  23 ->  34 ->  27 ->  19 ->  39 ->  20 -> 40
# Distance of the route: 694006m
#
# Maximum of the route distances: 694006m - 694.006km
# Objective: 35317
# Route for vehicle 0:
#  5 ->  8 ->  4 ->  3 ->  6 ->  1 ->  7 ->  2 ->  0 ->  9 ->  10 -> 11
# Distance of the route: 35317m
#
# Maximum of the route distances: 35317m - 35.317km
# Objective: 35317
# Route for vehicle 0:
#  5 ->  8 ->  4 ->  3 ->  6 ->  1 ->  7 ->  2 ->  0 ->  9 ->  10 -> 11
# Distance of the route: 35317m
#
# Maximum of the route distances: 35317m - 35.317km
# Objective: 917160
# Route for vehicle 0:
#  1 ->  94 ->  84 ->  86 ->  83 ->  62 ->  52 ->  71 ->  74 ->  56 ->  10 ->  68 ->  41 ->  59 ->  53 ->  33 ->  45 ->  12 ->  27 ->  65 ->  54 ->  47 ->  39 ->  42 ->  90 ->  30 ->  11 ->  61 ->  29 ->  51 ->  55 ->  34 ->  60 ->  44 ->  48 ->  85 ->  18 ->  15 ->  14 ->  16 ->  87 ->  13 ->  19 ->  79 ->  81 ->  63 ->  76 ->  20 ->  0 ->  36 ->  73 ->  46 ->  37 ->  66 ->  17 ->  92 ->  38 ->  35 ->  49 ->  23 ->  21 ->  93 ->  32 ->  22 ->  7 ->  6 ->  91 ->  40 ->  3 ->  5 ->  2 ->  89 ->  4 ->  9 ->  24 ->  67 ->  8 ->  26 ->  25 ->  28 ->  75 ->  57 ->  31 ->  69 ->  64 ->  70 ->  72 ->  50 ->  43 ->  80 ->  78 ->  77 ->  58 ->  82 -> 88
# Distance of the route: 917160m
#
# Maximum of the route distances: 917160m - 917.16km
# Objective: 915637
# Route for vehicle 0:
#  1 ->  94 ->  84 ->  86 ->  83 ->  62 ->  52 ->  71 ->  74 ->  56 ->  10 ->  68 ->  41 ->  59 ->  53 ->  33 ->  45 ->  12 ->  27 ->  65 ->  54 ->  47 ->  39 ->  42 ->  90 ->  30 ->  11 ->  61 ->  89 ->  4 ->  2 ->  5 ->  3 ->  9 ->  24 ->  91 ->  40 ->  29 ->  51 ->  22 ->  32 ->  7 ->  6 ->  67 ->  8 ->  26 ->  25 ->  28 ->  92 ->  38 ->  17 ->  35 ->  49 ->  23 ->  93 ->  21 ->  55 ->  34 ->  60 ->  44 ->  48 ->  85 ->  18 ->  15 ->  14 ->  16 ->  87 ->  13 ->  19 ->  79 ->  81 ->  63 ->  37 ->  66 ->  46 ->  73 ->  76 ->  36 ->  0 ->  20 ->  69 ->  64 ->  70 ->  31 ->  57 ->  75 ->  72 ->  50 ->  43 ->  80 ->  78 ->  77 ->  58 ->  82 -> 88
# Distance of the route: 915637m
#
# Maximum of the route distances: 915637m - 915.637km
# Objective: 371773
# Route for vehicle 0:
#  13 ->  24 ->  9 ->  11 ->  18 ->  26 ->  8 ->  25 ->  23 ->  114 ->  86 ->  16 ->  21 ->  5 ->  140 ->  118 ->  12 ->  74 ->  3 ->  10 ->  7 ->  126 ->  144 ->  147 ->  127 ->  104 ->  65 ->  62 ->  80 ->  84 ->  53 ->  48 ->  52 ->  64 ->  122 ->  56 ->  124 ->  123 ->  67 ->  47 ->  121 ->  35 ->  92 ->  109 ->  49 ->  57 ->  91 ->  34 ->  54 ->  83 ->  29 ->  40 ->  51 ->  110 ->  60 ->  96 ->  78 ->  45 ->  101 ->  44 ->  76 ->  108 ->  38 ->  105 ->  63 ->  58 ->  37 ->  55 ->  43 ->  115 ->  39 ->  72 ->  50 ->  41 ->  42 ->  102 ->  61 ->  70 ->  68 ->  89 ->  120 ->  139 ->  132 ->  100 ->  71 ->  59 ->  73 ->  128 ->  116 ->  119 ->  98 ->  77 ->  0 ->  93 ->  107 ->  33 ->  94 ->  1 ->  141 ->  95 ->  133 ->  138 ->  134 ->  130 ->  131 ->  103 ->  81 ->  69 ->  46 ->  66 ->  87 ->  90 ->  75 ->  31 ->  99 ->  32 ->  36 ->  137 ->  88 ->  97 ->  28 ->  30 ->  146 ->  4 ->  125 ->  82 ->  113 ->  145 ->  142 ->  129 ->  112 ->  135 ->  106 ->  136 ->  85 ->  111 ->  15 ->  6 ->  22 ->  143 ->  79 ->  20 ->  2 ->  19 ->  117 ->  14 ->  17 -> 27
# Distance of the route: 371773m
#
# Maximum of the route distances: 371773m - 371.773km
# Objective: 370892
# Route for vehicle 0:
#  13 ->  24 ->  9 ->  11 ->  18 ->  26 ->  8 ->  25 ->  23 ->  114 ->  86 ->  16 ->  21 ->  5 ->  140 ->  118 ->  12 ->  74 ->  3 ->  10 ->  7 ->  126 ->  144 ->  147 ->  127 ->  104 ->  65 ->  62 ->  80 ->  84 ->  53 ->  48 ->  52 ->  64 ->  122 ->  56 ->  124 ->  123 ->  67 ->  47 ->  121 ->  35 ->  92 ->  109 ->  49 ->  57 ->  91 ->  34 ->  54 ->  83 ->  29 ->  40 ->  51 ->  110 ->  60 ->  96 ->  78 ->  45 ->  101 ->  44 ->  76 ->  108 ->  38 ->  105 ->  63 ->  58 ->  37 ->  55 ->  43 ->  115 ->  39 ->  72 ->  50 ->  41 ->  42 ->  102 ->  61 ->  70 ->  68 ->  89 ->  120 ->  139 ->  132 ->  100 ->  71 ->  59 ->  73 ->  128 ->  116 ->  119 ->  98 ->  77 ->  0 ->  93 ->  107 ->  33 ->  94 ->  1 ->  141 ->  133 ->  138 ->  134 ->  95 ->  146 ->  4 ->  30 ->  130 ->  131 ->  103 ->  81 ->  69 ->  66 ->  46 ->  28 ->  87 ->  90 ->  75 ->  31 ->  99 ->  32 ->  36 ->  137 ->  88 ->  97 ->  125 ->  82 ->  113 ->  145 ->  142 ->  129 ->  112 ->  135 ->  106 ->  136 ->  85 ->  111 ->  15 ->  6 ->  22 ->  143 ->  79 ->  20 ->  2 ->  19 ->  117 ->  14 ->  17 -> 27
# Distance of the route: 370892m
#
# Maximum of the route distances: 370892m - 370.892km
# Objective: 694955
# Route for vehicle 0:
#  50 ->  49 ->  48 ->  46 ->  43 ->  45 ->  47 ->  44 ->  22 ->  21 ->  15 ->  13 ->  16 ->  20 ->  4 ->  6 ->  10 ->  1 ->  2 ->  0 ->  27 ->  26 ->  29 ->  7 ->  12 ->  17 ->  9 ->  19 ->  11 ->  5 ->  24 ->  30 ->  31 ->  18 ->  23 ->  14 ->  25 ->  8 ->  3 ->  33 ->  35 ->  34 ->  38 ->  36 ->  39 ->  37 ->  77 ->  28 ->  64 ->  66 ->  41 ->  69 ->  32 ->  73 ->  59 ->  56 ->  57 ->  52 ->  40 ->  62 ->  68 ->  54 ->  58 ->  53 ->  67 ->  42 ->  61 ->  51 ->  60 ->  55 ->  63 ->  65 ->  70 ->  74 ->  76 ->  93 ->  95 ->  94 ->  88 ->  84 ->  86 ->  87 ->  83 ->  90 ->  75 ->  71 ->  72 ->  80 ->  81 ->  82 ->  92 ->  91 ->  85 ->  89 ->  96 ->  79 -> 78
# Distance of the route: 694955m
#
# Maximum of the route distances: 694955m - 694.955km
# Objective: 700596
# Route for vehicle 0:
#  50 ->  49 ->  48 ->  46 ->  43 ->  45 ->  47 ->  44 ->  22 ->  21 ->  15 ->  16 ->  13 ->  7 ->  12 ->  17 ->  9 ->  19 ->  24 ->  30 ->  25 ->  14 ->  31 ->  18 ->  23 ->  3 ->  8 ->  5 ->  11 ->  10 ->  1 ->  2 ->  0 ->  27 ->  26 ->  29 ->  20 ->  4 ->  6 ->  33 ->  35 ->  34 ->  38 ->  36 ->  39 ->  37 ->  77 ->  70 ->  65 ->  63 ->  55 ->  60 ->  51 ->  61 ->  58 ->  54 ->  68 ->  62 ->  40 ->  52 ->  41 ->  28 ->  64 ->  66 ->  69 ->  32 ->  73 ->  59 ->  56 ->  57 ->  53 ->  67 ->  42 ->  74 ->  76 ->  93 ->  95 ->  94 ->  88 ->  84 ->  86 ->  87 ->  83 ->  90 ->  75 ->  71 ->  72 ->  80 ->  81 ->  82 ->  92 ->  91 ->  85 ->  89 ->  96 ->  79 -> 78
# Distance of the route: 700596m
#
# Maximum of the route distances: 700596m - 700.596km
# Objective: 840272
# Route for vehicle 0:
#  25 ->  62 ->  61 ->  58 ->  54 ->  56 ->  57 ->  59 ->  55 ->  60 ->  23 ->  21 ->  24 ->  18 ->  72 ->  14 ->  5 ->  77 ->  13 ->  12 ->  73 ->  67 ->  10 ->  4 ->  2 ->  16 ->  6 ->  63 ->  75 ->  74 ->  71 ->  26 ->  65 ->  64 ->  68 ->  69 ->  70 ->  11 ->  7 ->  1 ->  8 ->  79 ->  0 ->  78 ->  66 ->  3 ->  76 ->  15 ->  9 ->  17 ->  19 ->  20 ->  22 ->  53 ->  39 ->  40 ->  44 ->  30 ->  43 ->  34 ->  52 ->  49 ->  45 ->  46 ->  47 ->  36 ->  42 ->  38 ->  35 ->  31 ->  37 ->  27 ->  28 ->  33 ->  29 ->  41 ->  32 ->  48 ->  51 -> 50
# Distance of the route: 840272m
#
# Maximum of the route distances: 840272m - 840.272km
# Objective: 838560
# Route for vehicle 0:
#  25 ->  62 ->  61 ->  58 ->  54 ->  56 ->  57 ->  59 ->  55 ->  60 ->  23 ->  21 ->  24 ->  18 ->  72 ->  14 ->  5 ->  77 ->  13 ->  12 ->  73 ->  71 ->  26 ->  65 ->  64 ->  68 ->  69 ->  70 ->  11 ->  7 ->  1 ->  8 ->  63 ->  6 ->  75 ->  74 ->  67 ->  10 ->  4 ->  2 ->  16 ->  66 ->  78 ->  0 ->  79 ->  3 ->  76 ->  15 ->  9 ->  17 ->  19 ->  20 ->  22 ->  52 ->  49 ->  45 ->  34 ->  43 ->  46 ->  47 ->  41 ->  32 ->  33 ->  29 ->  42 ->  36 ->  38 ->  27 ->  28 ->  37 ->  31 ->  35 ->  40 ->  44 ->  30 ->  53 ->  39 ->  48 ->  51 -> 50
# Distance of the route: 838560m
#
# Maximum of the route distances: 838560m - 838.56km
# Objective: 306963
# Route for vehicle 0:
#  40 ->  37 ->  33 ->  24 ->  21 ->  1 ->  30 ->  15 ->  31 ->  25 ->  13 ->  22 ->  28 ->  4 ->  35 ->  20 ->  10 ->  27 ->  0 ->  3 ->  11 ->  34 ->  26 ->  32 ->  6 ->  12 ->  36 ->  18 ->  16 ->  2 ->  17 ->  5 ->  9 ->  29 ->  14 ->  8 ->  23 ->  19 ->  7 ->  39 ->  38 -> 41
# Distance of the route: 306963m
#
# Maximum of the route distances: 306963m - 306.963km
# Objective: 309483
# Route for vehicle 0:
#  40 ->  25 ->  31 ->  13 ->  22 ->  28 ->  4 ->  26 ->  32 ->  6 ->  12 ->  36 ->  18 ->  16 ->  2 ->  17 ->  5 ->  9 ->  29 ->  14 ->  8 ->  7 ->  19 ->  23 ->  3 ->  34 ->  11 ->  0 ->  27 ->  10 ->  20 ->  35 ->  30 ->  15 ->  1 ->  21 ->  24 ->  37 ->  33 ->  39 ->  38 -> 41
# Distance of the route: 309483m
#
# Maximum of the route distances: 309483m - 309.483km
# Objective: 163951
# Route for vehicle 0:
#  20 ->  0 ->  15 ->  14 ->  1 ->  5 ->  3 ->  17 ->  11 ->  13 ->  2 ->  18 ->  4 ->  7 ->  6 ->  9 ->  10 ->  16 ->  12 ->  19 ->  8 ->  24 ->  23 ->  21 -> 22
# Distance of the route: 163951m
#
# Maximum of the route distances: 163951m - 163.951km
# Objective: 163951
# Route for vehicle 0:
#  20 ->  0 ->  15 ->  14 ->  1 ->  5 ->  3 ->  17 ->  11 ->  13 ->  2 ->  18 ->  4 ->  7 ->  6 ->  9 ->  10 ->  16 ->  12 ->  19 ->  8 ->  24 ->  23 ->  21 -> 22
# Distance of the route: 163951m
#
# Maximum of the route distances: 163951m - 163.951km
# Objective: 1569796
# Route for vehicle 0:
#  13 ->  21 ->  17 ->  12 ->  19 ->  15 ->  11 ->  18 ->  20 ->  10 ->  7 ->  16 ->  5 ->  2 ->  8 ->  58 ->  52 ->  36 ->  60 ->  54 ->  38 ->  49 ->  63 ->  33 ->  29 ->  32 ->  56 ->  47 ->  28 ->  39 ->  37 ->  30 ->  46 ->  31 ->  44 ->  64 ->  55 ->  6 ->  53 ->  50 ->  1 ->  62 ->  40 ->  57 ->  51 ->  34 ->  59 ->  45 ->  4 ->  43 ->  3 ->  0 ->  42 ->  41 ->  65 ->  27 ->  61 ->  48 ->  35 ->  9 ->  14 ->  22 ->  23 ->  26 ->  25 -> 24
# Distance of the route: 1569796m
#
# Maximum of the route distances: 1569796m - 1569.796km
# Objective: 1569796
# Route for vehicle 0:
#  13 ->  21 ->  17 ->  12 ->  19 ->  15 ->  11 ->  18 ->  20 ->  10 ->  7 ->  16 ->  5 ->  2 ->  8 ->  58 ->  52 ->  36 ->  60 ->  54 ->  38 ->  49 ->  63 ->  33 ->  29 ->  32 ->  56 ->  47 ->  28 ->  39 ->  37 ->  30 ->  46 ->  31 ->  44 ->  64 ->  55 ->  6 ->  53 ->  50 ->  1 ->  62 ->  40 ->  57 ->  51 ->  34 ->  59 ->  45 ->  4 ->  43 ->  3 ->  0 ->  42 ->  41 ->  65 ->  27 ->  61 ->  48 ->  35 ->  9 ->  14 ->  22 ->  23 ->  26 ->  25 -> 24
# Distance of the route: 1569796m
#
# Maximum of the route distances: 1569796m - 1569.796km
# Objective: 130507
# Route for vehicle 0:
#  0 ->  15 ->  13 ->  19 ->  10 ->  29 ->  30 ->  33 ->  21 ->  16 ->  18 ->  24 ->  7 ->  14 ->  1 ->  35 ->  12 ->  25 ->  8 ->  22 ->  2 ->  6 ->  5 ->  4 ->  20 ->  27 ->  23 ->  28 ->  17 ->  9 ->  32 ->  11 ->  36 ->  34 ->  26 ->  31 ->  3 -> 37
# Distance of the route: 130507m
#
# Maximum of the route distances: 130507m - 130.507km
# Objective: 130964
# Route for vehicle 0:
#  0 ->  15 ->  13 ->  19 ->  30 ->  29 ->  10 ->  27 ->  23 ->  28 ->  20 ->  4 ->  5 ->  12 ->  16 ->  33 ->  21 ->  18 ->  24 ->  14 ->  7 ->  35 ->  1 ->  25 ->  8 ->  22 ->  2 ->  6 ->  17 ->  9 ->  32 ->  11 ->  36 ->  34 ->  26 ->  31 ->  3 -> 37
# Distance of the route: 130964m
#
# Maximum of the route distances: 130964m - 130.964km
# Objective: 306803
# Route for vehicle 0:
#  88 ->  79 ->  87 ->  84 ->  91 ->  80 ->  39 ->  46 ->  37 ->  51 ->  0 ->  64 ->  43 ->  72 ->  8 ->  52 ->  49 ->  18 ->  14 ->  28 ->  42 ->  56 ->  76 ->  9 ->  11 ->  24 ->  16 ->  15 ->  65 ->  35 ->  61 ->  75 ->  74 ->  50 ->  82 ->  67 ->  33 ->  31 ->  73 ->  5 ->  63 ->  53 ->  7 ->  68 ->  66 ->  77 ->  32 ->  17 ->  20 ->  25 ->  22 ->  41 ->  44 ->  27 ->  34 ->  12 ->  19 ->  26 ->  60 ->  10 ->  1 ->  69 ->  6 ->  4 ->  40 ->  70 ->  21 ->  36 ->  2 ->  30 ->  45 ->  59 ->  55 ->  48 ->  3 ->  13 ->  58 ->  23 ->  54 ->  57 ->  78 ->  47 ->  29 ->  38 ->  90 ->  62 ->  83 ->  85 ->  71 ->  86 ->  81 -> 89
# Distance of the route: 306803m
#
# Maximum of the route distances: 306803m - 306.803km
# Objective: 316369
# Route for vehicle 0:
#  88 ->  79 ->  87 ->  84 ->  91 ->  80 ->  33 ->  31 ->  73 ->  5 ->  7 ->  53 ->  63 ->  15 ->  16 ->  24 ->  68 ->  66 ->  77 ->  32 ->  41 ->  44 ->  27 ->  34 ->  12 ->  19 ->  10 ->  60 ->  1 ->  69 ->  22 ->  25 ->  17 ->  20 ->  30 ->  2 ->  36 ->  21 ->  70 ->  40 ->  6 ->  4 ->  26 ->  9 ->  11 ->  76 ->  18 ->  14 ->  28 ->  42 ->  56 ->  65 ->  35 ->  61 ->  75 ->  74 ->  82 ->  67 ->  50 ->  64 ->  43 ->  72 ->  8 ->  52 ->  49 ->  54 ->  23 ->  58 ->  13 ->  3 ->  45 ->  59 ->  55 ->  48 ->  57 ->  78 ->  47 ->  29 ->  38 ->  46 ->  37 ->  51 ->  0 ->  39 ->  90 ->  62 ->  83 ->  85 ->  71 ->  86 ->  81 -> 89
# Distance of the route: 316369m
#
# Maximum of the route distances: 316369m - 316.369km
# Objective: 112572
# Route for vehicle 0:
#  17 ->  13 ->  21 ->  5 ->  22 ->  27 ->  15 ->  20 ->  12 ->  16 ->  24 ->  3 ->  19 ->  0 ->  10 ->  7 ->  28 ->  2 ->  11 ->  6 ->  26 ->  25 ->  8 ->  9 ->  1 ->  14 ->  4 ->  18 -> 23
# Distance of the route: 112572m
#
# Maximum of the route distances: 112572m - 112.572km
# Objective: 111654
# Route for vehicle 0:
#  17 ->  13 ->  21 ->  5 ->  22 ->  27 ->  15 ->  20 ->  12 ->  16 ->  24 ->  3 ->  25 ->  26 ->  6 ->  11 ->  19 ->  0 ->  10 ->  7 ->  28 ->  2 ->  8 ->  9 ->  1 ->  14 ->  4 ->  18 -> 23
# Distance of the route: 111654m
#
# Maximum of the route distances: 111654m - 111.654km
# Objective: 70205
# Route for vehicle 0:
#  16 ->  8 ->  0 ->  10 ->  2 ->  14 ->  4 ->  9 ->  3 ->  11 ->  6 ->  1 ->  7 ->  12 ->  15 ->  13 ->  5 ->  17 ->  18 -> 19
# Distance of the route: 70205m
#
# Maximum of the route distances: 70205m - 70.205km
# Objective: 70205
# Route for vehicle 0:
#  16 ->  8 ->  0 ->  10 ->  2 ->  14 ->  4 ->  9 ->  3 ->  11 ->  6 ->  1 ->  7 ->  12 ->  15 ->  13 ->  5 ->  17 ->  18 -> 19
# Distance of the route: 70205m
#
# Maximum of the route distances: 70205m - 70.205km
# Objective: 513150
# Route for vehicle 0:
#  41 ->  42 ->  43 ->  40 ->  19 ->  20 ->  1 ->  36 ->  27 ->  33 ->  24 ->  11 ->  2 ->  18 ->  31 ->  14 ->  6 ->  32 ->  8 ->  5 ->  3 ->  22 ->  4 ->  13 ->  0 ->  10 ->  7 ->  23 ->  21 ->  15 ->  34 ->  12 ->  25 ->  16 ->  30 ->  28 ->  17 ->  9 ->  35 ->  37 ->  29 ->  38 ->  39 ->  26 ->  45 ->  46 -> 44
# Distance of the route: 513150m
#
# Maximum of the route distances: 513150m - 513.15km
# Objective: 517813
# Route for vehicle 0:
#  41 ->  42 ->  43 ->  40 ->  19 ->  32 ->  8 ->  5 ->  3 ->  22 ->  4 ->  11 ->  2 ->  18 ->  31 ->  14 ->  6 ->  27 ->  20 ->  1 ->  36 ->  33 ->  24 ->  21 ->  23 ->  13 ->  7 ->  10 ->  0 ->  15 ->  34 ->  12 ->  25 ->  16 ->  30 ->  28 ->  17 ->  9 ->  35 ->  37 ->  29 ->  38 ->  39 ->  26 ->  45 ->  46 -> 44
# Distance of the route: 517813m
#
# Maximum of the route distances: 517813m - 517.813km
# Objective: 226584
# Route for vehicle 0:
#  40 ->  37 ->  28 ->  20 ->  32 ->  25 ->  51 ->  27 ->  16 ->  26 ->  13 ->  9 ->  1 ->  47 ->  6 ->  18 ->  2 ->  30 ->  14 ->  21 ->  23 ->  31 ->  4 ->  29 ->  22 ->  33 ->  3 ->  7 ->  49 ->  0 ->  12 ->  48 ->  5 ->  11 ->  17 ->  8 ->  19 ->  24 ->  10 ->  34 ->  15 ->  46 ->  35 ->  42 ->  44 ->  38 ->  39 ->  36 ->  43 ->  50 ->  45 -> 41
# Distance of the route: 226584m
#
# Maximum of the route distances: 226584m - 226.584km
# Objective: 227734
# Route for vehicle 0:
#  40 ->  37 ->  23 ->  21 ->  14 ->  30 ->  31 ->  4 ->  7 ->  49 ->  0 ->  12 ->  48 ->  2 ->  18 ->  6 ->  47 ->  1 ->  9 ->  13 ->  28 ->  20 ->  32 ->  25 ->  51 ->  27 ->  16 ->  26 ->  11 ->  5 ->  17 ->  8 ->  19 ->  3 ->  29 ->  22 ->  33 ->  34 ->  15 ->  10 ->  24 ->  46 ->  35 ->  42 ->  44 ->  38 ->  39 ->  36 ->  43 ->  50 ->  45 -> 41
# Distance of the route: 227734m
#
# Maximum of the route distances: 227734m - 227.734km
# Objective: 756704
# Route for vehicle 0:
#  48 ->  44 ->  110 ->  109 ->  108 ->  39 ->  41 ->  34 ->  36 ->  38 ->  33 ->  37 ->  35 ->  42 ->  43 ->  45 ->  40 ->  46 ->  47 ->  49 ->  102 ->  101 ->  99 ->  100 ->  103 ->  91 ->  146 ->  90 ->  106 ->  105 ->  8 ->  50 ->  83 ->  153 ->  71 ->  76 ->  77 ->  64 ->  66 ->  29 ->  65 ->  138 ->  75 ->  72 ->  151 ->  20 ->  124 ->  28 ->  88 ->  113 ->  74 ->  31 ->  55 ->  86 ->  78 ->  142 ->  59 ->  95 ->  80 ->  160 ->  93 ->  159 ->  111 ->  53 ->  140 ->  135 ->  125 ->  133 ->  89 ->  30 ->  82 ->  68 ->  27 ->  149 ->  4 ->  18 ->  16 ->  122 ->  129 ->  141 ->  128 ->  19 ->  73 ->  25 ->  61 ->  120 ->  12 ->  15 ->  9 ->  63 ->  3 ->  67 ->  23 ->  98 ->  1 ->  94 ->  132 ->  123 ->  121 ->  6 ->  26 ->  117 ->  21 ->  147 ->  14 ->  11 ->  5 ->  56 ->  130 ->  17 ->  79 ->  118 ->  58 ->  131 ->  10 ->  0 ->  112 ->  137 ->  60 ->  13 ->  148 ->  134 ->  150 ->  162 ->  62 ->  145 ->  136 ->  92 ->  96 ->  126 ->  127 ->  24 ->  87 ->  85 ->  57 ->  7 ->  156 ->  152 ->  143 ->  51 ->  119 ->  69 ->  32 ->  54 ->  52 ->  70 ->  157 ->  139 ->  155 ->  154 ->  81 ->  97 ->  2 ->  22 ->  158 ->  84 ->  104 ->  144 ->  163 ->  107 ->  161 ->  116 ->  114 -> 115
# Distance of the route: 756704m
#
# Maximum of the route distances: 756704m - 756.704km
# Objective: 769365
# Route for vehicle 0:
#  48 ->  44 ->  110 ->  109 ->  108 ->  107 ->  161 ->  163 ->  144 ->  104 ->  84 ->  158 ->  22 ->  2 ->  97 ->  81 ->  154 ->  155 ->  139 ->  157 ->  70 ->  52 ->  54 ->  32 ->  18 ->  4 ->  149 ->  27 ->  68 ->  82 ->  135 ->  140 ->  125 ->  133 ->  53 ->  111 ->  159 ->  30 ->  89 ->  151 ->  72 ->  75 ->  124 ->  20 ->  160 ->  93 ->  59 ->  95 ->  80 ->  74 ->  113 ->  88 ->  28 ->  138 ->  65 ->  29 ->  66 ->  64 ->  77 ->  76 ->  71 ->  153 ->  83 ->  150 ->  134 ->  162 ->  136 ->  145 ->  62 ->  148 ->  13 ->  60 ->  137 ->  112 ->  0 ->  10 ->  131 ->  58 ->  118 ->  79 ->  17 ->  130 ->  56 ->  5 ->  11 ->  14 ->  147 ->  21 ->  117 ->  26 ->  6 ->  121 ->  123 ->  132 ->  94 ->  1 ->  98 ->  23 ->  67 ->  3 ->  63 ->  9 ->  15 ->  12 ->  120 ->  61 ->  25 ->  73 ->  19 ->  128 ->  141 ->  129 ->  122 ->  16 ->  119 ->  69 ->  51 ->  143 ->  152 ->  156 ->  7 ->  57 ->  85 ->  87 ->  24 ->  127 ->  126 ->  96 ->  92 ->  50 ->  8 ->  105 ->  106 ->  90 ->  146 ->  55 ->  31 ->  86 ->  142 ->  78 ->  91 ->  103 ->  100 ->  99 ->  101 ->  39 ->  41 ->  34 ->  36 ->  38 ->  33 ->  37 ->  35 ->  42 ->  43 ->  45 ->  40 ->  46 ->  47 ->  49 ->  102 ->  116 ->  114 -> 115
# Distance of the route: 769365m
#
# Maximum of the route distances: 769365m - 769.365km
# Objective: 555098
# Route for vehicle 0:
#  17 ->  15 ->  14 ->  12 ->  5 ->  4 ->  9 ->  13 ->  1 ->  7 ->  11 ->  8 ->  0 ->  2 ->  6 ->  10 ->  3 ->  16 ->  92 ->  95 ->  96 ->  94 ->  73 ->  54 ->  80 ->  74 ->  77 ->  55 ->  46 ->  67 ->  53 ->  57 ->  24 ->  23 ->  18 ->  69 ->  52 ->  36 ->  26 ->  41 ->  65 ->  35 ->  43 ->  29 ->  45 ->  48 ->  28 ->  31 ->  37 ->  20 ->  27 ->  78 ->  68 ->  76 ->  79 ->  42 ->  60 ->  89 ->  83 ->  49 ->  50 ->  19 ->  64 ->  30 ->  72 ->  75 ->  22 ->  84 ->  85 ->  38 ->  44 ->  33 ->  61 ->  34 ->  25 ->  59 ->  62 ->  71 ->  70 ->  56 ->  81 ->  32 ->  39 ->  40 ->  21 ->  58 ->  51 ->  63 ->  90 ->  47 ->  87 ->  86 ->  82 ->  66 ->  91 ->  88 -> 93
# Distance of the route: 555098m
#
# Maximum of the route distances: 555098m - 555.098km
# Objective: 553995
# Route for vehicle 0:
#  17 ->  15 ->  14 ->  9 ->  4 ->  13 ->  5 ->  12 ->  1 ->  7 ->  11 ->  8 ->  0 ->  2 ->  6 ->  10 ->  3 ->  16 ->  92 ->  95 ->  96 ->  94 ->  73 ->  54 ->  80 ->  74 ->  77 ->  55 ->  46 ->  67 ->  57 ->  53 ->  43 ->  29 ->  45 ->  48 ->  28 ->  35 ->  65 ->  36 ->  52 ->  24 ->  23 ->  18 ->  69 ->  25 ->  59 ->  61 ->  33 ->  44 ->  26 ->  41 ->  31 ->  37 ->  20 ->  27 ->  75 ->  72 ->  30 ->  64 ->  49 ->  50 ->  19 ->  60 ->  42 ->  79 ->  76 ->  78 ->  68 ->  89 ->  83 ->  91 ->  66 ->  82 ->  86 ->  87 ->  90 ->  47 ->  21 ->  40 ->  39 ->  32 ->  81 ->  71 ->  70 ->  56 ->  22 ->  84 ->  85 ->  38 ->  34 ->  62 ->  58 ->  51 ->  63 ->  88 -> 93
# Distance of the route: 553995m
#
# Maximum of the route distances: 553995m - 553.995km
# Objective: 673492
# Route for vehicle 0:
#  42 ->  41 ->  39 ->  38 ->  36 ->  33 ->  35 ->  37 ->  34 ->  43 ->  52 ->  54 ->  55 ->  56 ->  44 ->  47 ->  51 ->  49 ->  50 ->  59 ->  58 ->  46 ->  60 ->  48 ->  24 ->  25 ->  26 ->  53 ->  22 ->  23 ->  21 ->  15 ->  8 ->  17 ->  14 ->  10 ->  30 ->  5 ->  29 ->  11 ->  31 ->  6 ->  2 ->  16 ->  32 ->  3 ->  13 ->  1 ->  9 ->  7 ->  4 ->  12 ->  18 ->  19 ->  20 ->  27 ->  28 ->  57 ->  40 ->  0 -> 45
# Distance of the route: 673492m
#
# Maximum of the route distances: 673492m - 673.492km
# Objective: 674341
# Route for vehicle 0:
#  42 ->  41 ->  39 ->  38 ->  36 ->  33 ->  35 ->  37 ->  34 ->  43 ->  52 ->  54 ->  55 ->  56 ->  44 ->  47 ->  51 ->  49 ->  50 ->  59 ->  58 ->  46 ->  60 ->  48 ->  24 ->  25 ->  26 ->  53 ->  22 ->  23 ->  21 ->  15 ->  8 ->  17 ->  32 ->  3 ->  16 ->  13 ->  31 ->  11 ->  6 ->  2 ->  14 ->  10 ->  30 ->  29 ->  5 ->  7 ->  9 ->  1 ->  4 ->  12 ->  18 ->  19 ->  20 ->  27 ->  28 ->  57 ->  40 ->  0 -> 45
# Distance of the route: 674341m
#
# Maximum of the route distances: 674341m - 674.341km
# Objective: 268857
# Route for vehicle 0:
#  23 ->  25 ->  22 ->  20 ->  15 ->  13 ->  4 ->  6 ->  3 ->  16 ->  12 ->  10 ->  5 ->  9 ->  14 ->  17 ->  1 ->  7 ->  8 ->  2 ->  11 ->  19 ->  18 ->  0 ->  24 ->  21 -> 26
# Distance of the route: 268857m
#
# Maximum of the route distances: 268857m - 268.857km
# Objective: 271434
# Route for vehicle 0:
#  23 ->  25 ->  22 ->  20 ->  15 ->  13 ->  4 ->  6 ->  3 ->  16 ->  12 ->  10 ->  5 ->  2 ->  11 ->  8 ->  7 ->  1 ->  17 ->  9 ->  14 ->  18 ->  19 ->  0 ->  24 ->  21 -> 26
# Distance of the route: 271434m
#
# Maximum of the route distances: 271434m - 271.434km
# Objective: 296017
# Route for vehicle 0:
#  37 ->  17 ->  34 ->  18 ->  24 ->  26 ->  0 ->  19 ->  31 ->  22 ->  16 ->  33 ->  7 ->  32 ->  11 ->  4 ->  23 ->  20 ->  14 ->  10 ->  27 ->  13 ->  1 ->  25 ->  3 ->  2 ->  5 ->  12 ->  28 ->  6 ->  35 ->  15 ->  9 ->  21 ->  8 ->  38 ->  30 ->  110 ->  106 ->  73 ->  95 ->  94 ->  96 ->  92 ->  91 ->  71 ->  90 ->  85 ->  75 ->  63 ->  81 ->  60 ->  47 ->  50 ->  57 ->  46 ->  72 ->  76 ->  36 ->  44 ->  43 ->  66 ->  82 ->  49 ->  74 ->  54 ->  40 ->  70 ->  45 ->  51 ->  84 ->  65 ->  55 ->  52 ->  53 ->  56 ->  29 ->  48 ->  68 ->  67 ->  58 ->  39 ->  61 ->  62 ->  89 ->  78 ->  77 ->  83 ->  93 ->  99 ->  103 ->  88 ->  105 ->  87 ->  69 ->  79 ->  101 ->  80 ->  100 ->  59 ->  64 ->  86 ->  41 ->  104 ->  102 ->  42 ->  97 ->  98 ->  107 ->  108 ->  109 -> 111
# Distance of the route: 296017m
#
# Maximum of the route distances: 296017m - 296.017km
# Objective: 330661
# Route for vehicle 0:
#  37 ->  31 ->  16 ->  22 ->  19 ->  0 ->  26 ->  24 ->  17 ->  34 ->  18 ->  25 ->  3 ->  30 ->  38 ->  8 ->  21 ->  9 ->  15 ->  6 ->  28 ->  12 ->  2 ->  5 ->  1 ->  4 ->  23 ->  20 ->  11 ->  32 ->  7 ->  33 ->  14 ->  10 ->  27 ->  13 ->  35 ->  107 ->  108 ->  98 ->  97 ->  42 ->  102 ->  104 ->  41 ->  86 ->  80 ->  100 ->  64 ->  59 ->  39 ->  58 ->  67 ->  68 ->  48 ->  40 ->  45 ->  70 ->  54 ->  74 ->  49 ->  82 ->  66 ->  43 ->  50 ->  47 ->  81 ->  60 ->  44 ->  36 ->  76 ->  72 ->  46 ->  57 ->  92 ->  91 ->  96 ->  94 ->  95 ->  73 ->  110 ->  106 ->  71 ->  90 ->  85 ->  75 ->  63 ->  65 ->  55 ->  84 ->  51 ->  56 ->  29 ->  53 ->  52 ->  89 ->  62 ->  61 ->  78 ->  77 ->  83 ->  93 ->  99 ->  103 ->  87 ->  69 ->  79 ->  101 ->  88 ->  105 ->  109 -> 111
# Distance of the route: 330661m
#
# Maximum of the route distances: 330661m - 330.661km
# Objective: 411604
# Route for vehicle 0:
#  36 ->  47 ->  33 ->  16 ->  10 ->  23 ->  48 ->  9 ->  18 ->  6 ->  3 ->  29 ->  24 ->  43 ->  20 ->  27 ->  17 ->  4 ->  8 ->  32 ->  28 ->  31 ->  45 ->  25 ->  34 ->  19 ->  40 ->  5 ->  46 ->  41 ->  30 ->  1 ->  2 ->  35 ->  11 ->  21 ->  0 ->  7 ->  12 ->  15 ->  42 ->  14 ->  13 ->  44 ->  26 ->  22 ->  49 ->  37 ->  38 ->  39 ->  58 ->  54 ->  55 ->  57 ->  52 ->  53 ->  50 ->  56 -> 51
# Distance of the route: 411604m
#
# Maximum of the route distances: 411604m - 411.604km
# Objective: 411411
# Route for vehicle 0:
#  36 ->  6 ->  3 ->  29 ->  17 ->  4 ->  32 ->  8 ->  27 ->  20 ->  43 ->  24 ->  48 ->  9 ->  18 ->  47 ->  33 ->  16 ->  10 ->  23 ->  44 ->  13 ->  0 ->  7 ->  21 ->  11 ->  35 ->  2 ->  1 ->  30 ->  41 ->  46 ->  5 ->  40 ->  19 ->  34 ->  25 ->  45 ->  28 ->  31 ->  12 ->  15 ->  42 ->  14 ->  26 ->  22 ->  49 ->  37 ->  38 ->  39 ->  58 ->  54 ->  55 ->  57 ->  52 ->  53 ->  50 ->  56 -> 51
# Distance of the route: 411411m
#
# Maximum of the route distances: 411411m - 411.411km
# Objective: 643081
# Route for vehicle 0:
#  64 ->  90 ->  81 ->  70 ->  71 ->  73 ->  74 ->  89 ->  87 ->  72 ->  83 ->  82 ->  88 ->  76 ->  75 ->  85 ->  80 ->  79 ->  86 ->  77 ->  78 ->  84 ->  91 ->  63 ->  65 ->  92 ->  51 ->  48 ->  25 ->  109 ->  34 ->  24 ->  26 ->  111 ->  39 ->  98 ->  95 ->  104 ->  32 ->  110 ->  33 ->  40 ->  102 ->  28 ->  108 ->  30 ->  38 ->  67 ->  96 ->  94 ->  27 ->  41 ->  106 ->  35 ->  36 ->  97 ->  112 ->  37 ->  100 ->  101 ->  29 ->  99 ->  93 ->  31 ->  103 ->  66 ->  105 ->  42 ->  107 ->  46 ->  47 ->  44 ->  49 ->  43 ->  50 ->  45 ->  14 ->  16 ->  17 ->  13 ->  4 ->  2 ->  7 ->  5 ->  131 ->  3 ->  142 ->  148 ->  119 ->  133 ->  132 ->  134 ->  123 ->  125 ->  121 ->  117 ->  115 ->  127 ->  137 ->  129 ->  145 ->  144 ->  141 ->  68 ->  128 ->  151 ->  150 ->  130 ->  61 ->  116 ->  140 ->  118 ->  136 ->  0 ->  114 ->  147 ->  149 ->  120 ->  69 ->  122 ->  1 ->  126 ->  135 ->  124 ->  139 ->  138 ->  143 ->  146 ->  6 ->  8 ->  9 ->  11 ->  10 ->  18 ->  23 ->  12 ->  21 ->  22 ->  20 ->  15 ->  19 ->  62 ->  59 ->  60 ->  56 ->  57 ->  53 ->  54 ->  55 ->  52 ->  58 -> 113
# Distance of the route: 643081m
#
# Maximum of the route distances: 643081m - 643.081km
# Objective: 642395
# Route for vehicle 0:
#  64 ->  90 ->  81 ->  70 ->  71 ->  73 ->  74 ->  89 ->  87 ->  72 ->  76 ->  88 ->  83 ->  82 ->  79 ->  86 ->  77 ->  80 ->  85 ->  75 ->  78 ->  84 ->  91 ->  63 ->  65 ->  92 ->  51 ->  48 ->  25 ->  109 ->  34 ->  24 ->  26 ->  111 ->  39 ->  98 ->  95 ->  37 ->  112 ->  32 ->  104 ->  110 ->  33 ->  40 ->  102 ->  28 ->  108 ->  30 ->  38 ->  67 ->  96 ->  94 ->  27 ->  41 ->  106 ->  35 ->  97 ->  36 ->  100 ->  101 ->  29 ->  99 ->  93 ->  31 ->  103 ->  66 ->  105 ->  42 ->  107 ->  46 ->  47 ->  44 ->  49 ->  43 ->  50 ->  45 ->  14 ->  16 ->  17 ->  13 ->  4 ->  2 ->  7 ->  5 ->  131 ->  3 ->  142 ->  148 ->  119 ->  133 ->  132 ->  134 ->  123 ->  125 ->  121 ->  117 ->  115 ->  127 ->  137 ->  129 ->  145 ->  144 ->  141 ->  68 ->  128 ->  151 ->  150 ->  130 ->  61 ->  116 ->  140 ->  118 ->  136 ->  0 ->  114 ->  147 ->  149 ->  120 ->  69 ->  122 ->  1 ->  126 ->  135 ->  124 ->  139 ->  138 ->  143 ->  146 ->  6 ->  8 ->  9 ->  11 ->  10 ->  18 ->  23 ->  12 ->  21 ->  22 ->  20 ->  15 ->  19 ->  62 ->  59 ->  60 ->  56 ->  57 ->  53 ->  54 ->  55 ->  52 ->  58 -> 113
# Distance of the route: 642395m
#
# Maximum of the route distances: 642395m - 642.395km
# Objective: 579278
# Route for vehicle 0:
#  3 ->  5 ->  41 ->  1 ->  37 ->  26 ->  34 ->  36 ->  32 ->  21 ->  39 ->  23 ->  38 ->  18 ->  40 ->  28 ->  24 ->  25 ->  35 ->  27 ->  30 ->  29 ->  20 ->  19 ->  31 ->  22 ->  33 ->  42 ->  46 ->  17 ->  16 ->  2 ->  0 ->  45 ->  43 ->  47 ->  44 ->  12 ->  13 ->  14 ->  11 ->  10 ->  15 ->  8 ->  7 ->  9 ->  6 -> 4
# Distance of the route: 579278m
#
# Maximum of the route distances: 579278m - 579.278km
# Objective: 580230
# Route for vehicle 0:
#  3 ->  5 ->  41 ->  1 ->  37 ->  26 ->  34 ->  40 ->  28 ->  24 ->  25 ->  27 ->  35 ->  18 ->  38 ->  23 ->  36 ->  32 ->  21 ->  39 ->  19 ->  31 ->  22 ->  20 ->  29 ->  30 ->  33 ->  42 ->  46 ->  17 ->  16 ->  2 ->  0 ->  45 ->  43 ->  47 ->  44 ->  12 ->  13 ->  14 ->  11 ->  10 ->  15 ->  8 ->  7 ->  9 ->  6 -> 4
# Distance of the route: 580230m
#
# Maximum of the route distances: 580230m - 580.23km
# Objective: 426617
# Route for vehicle 0:
#  21 ->  14 ->  11 ->  12 ->  18 ->  16 ->  15 ->  17 ->  13 ->  20 ->  19 ->  22 ->  23 ->  10 ->  9 ->  5 ->  4 ->  46 ->  41 ->  37 ->  40 ->  0 ->  7 ->  49 ->  44 ->  32 ->  45 ->  33 ->  2 ->  39 ->  3 ->  1 ->  42 ->  35 ->  38 ->  31 ->  34 ->  43 ->  47 ->  6 ->  8 ->  48 ->  36 ->  51 ->  50 ->  24 ->  29 ->  27 ->  25 ->  26 ->  28 -> 30
# Distance of the route: 426617m
#
# Maximum of the route distances: 426617m - 426.617km
# Objective: 426994
# Route for vehicle 0:
#  21 ->  14 ->  11 ->  12 ->  18 ->  16 ->  15 ->  17 ->  13 ->  20 ->  19 ->  22 ->  23 ->  10 ->  9 ->  5 ->  4 ->  46 ->  41 ->  37 ->  40 ->  0 ->  7 ->  49 ->  44 ->  32 ->  1 ->  42 ->  35 ->  38 ->  3 ->  31 ->  34 ->  43 ->  39 ->  45 ->  33 ->  2 ->  47 ->  6 ->  8 ->  48 ->  36 ->  51 ->  50 ->  24 ->  29 ->  27 ->  25 ->  26 ->  28 -> 30
# Distance of the route: 426994m
#
# Maximum of the route distances: 426994m - 426.994km
# Objective: 229993
# Route for vehicle 0:
#  3 ->  0 ->  7 ->  123 ->  6 ->  4 ->  5 ->  1 ->  127 ->  116 ->  118 ->  14 ->  87 ->  40 ->  125 ->  98 ->  120 ->  78 ->  88 ->  101 ->  106 ->  117 ->  52 ->  112 ->  99 ->  107 ->  45 ->  44 ->  10 ->  9 ->  97 ->  20 ->  42 ->  84 ->  66 ->  57 ->  61 ->  75 ->  59 ->  65 ->  17 ->  49 ->  85 ->  67 ->  113 ->  128 ->  53 ->  103 ->  105 ->  111 ->  70 ->  126 ->  15 ->  114 ->  95 ->  121 ->  18 ->  82 ->  28 ->  72 ->  62 ->  11 ->  24 ->  39 ->  35 ->  64 ->  60 ->  41 ->  56 ->  100 ->  16 ->  48 ->  27 ->  83 ->  36 ->  31 ->  37 ->  68 ->  73 ->  12 ->  33 ->  38 ->  51 ->  43 ->  115 ->  34 ->  47 ->  58 ->  69 ->  71 ->  32 ->  77 ->  63 ->  30 ->  46 ->  13 ->  108 ->  124 ->  102 ->  74 ->  89 ->  54 ->  86 ->  21 ->  29 ->  8 ->  90 ->  104 ->  96 ->  76 ->  19 ->  119 ->  129 ->  109 ->  79 ->  94 ->  122 ->  55 ->  81 ->  91 ->  93 ->  92 ->  110 ->  50 ->  23 ->  80 ->  130 ->  26 ->  25 ->  2 -> 22
# Distance of the route: 229993m
#
# Maximum of the route distances: 229993m - 229.993km
# Objective: 234792
# Route for vehicle 0:
#  3 ->  0 ->  7 ->  123 ->  6 ->  4 ->  5 ->  1 ->  127 ->  116 ->  106 ->  117 ->  52 ->  112 ->  99 ->  37 ->  68 ->  73 ->  12 ->  33 ->  71 ->  69 ->  58 ->  32 ->  77 ->  13 ->  46 ->  124 ->  102 ->  110 ->  50 ->  23 ->  80 ->  130 ->  26 ->  25 ->  2 ->  129 ->  119 ->  79 ->  109 ->  54 ->  89 ->  81 ->  55 ->  122 ->  94 ->  92 ->  93 ->  91 ->  74 ->  108 ->  30 ->  63 ->  47 ->  34 ->  115 ->  43 ->  51 ->  38 ->  27 ->  83 ->  36 ->  31 ->  100 ->  16 ->  48 ->  56 ->  41 ->  60 ->  64 ->  35 ->  39 ->  24 ->  11 ->  62 ->  72 ->  28 ->  82 ->  18 ->  121 ->  95 ->  114 ->  15 ->  126 ->  70 ->  67 ->  85 ->  49 ->  17 ->  65 ->  59 ->  75 ->  61 ->  57 ->  45 ->  107 ->  44 ->  10 ->  9 ->  66 ->  84 ->  42 ->  20 ->  97 ->  98 ->  120 ->  78 ->  88 ->  101 ->  125 ->  40 ->  87 ->  118 ->  14 ->  113 ->  105 ->  103 ->  111 ->  104 ->  86 ->  21 ->  29 ->  8 ->  90 ->  76 ->  19 ->  96 ->  53 ->  128 -> 22
# Distance of the route: 234792m
#
# Maximum of the route distances: 234792m - 234.792km
# Objective: 785314
# Route for vehicle 0:
#  0 ->  65 ->  43 ->  64 ->  13 ->  37 ->  58 ->  42 ->  50 ->  33 ->  45 ->  23 ->  51 ->  26 ->  49 ->  48 ->  6 ->  53 ->  46 ->  22 ->  31 ->  41 ->  40 ->  28 ->  30 ->  9 ->  8 ->  29 ->  14 ->  1 ->  59 ->  39 ->  2 ->  12 ->  5 ->  24 ->  54 ->  11 ->  36 ->  10 ->  63 ->  47 ->  38 ->  44 ->  25 ->  27 ->  35 ->  61 ->  20 ->  60 ->  21 ->  19 ->  34 ->  7 ->  15 ->  18 ->  32 ->  56 ->  52 ->  4 ->  17 ->  62 ->  16 ->  3 ->  57 ->  55 ->  67 ->  66 ->  76 ->  78 ->  75 ->  72 ->  73 ->  74 ->  79 ->  77 ->  80 ->  69 ->  70 ->  68 -> 71
# Distance of the route: 785314m
#
# Maximum of the route distances: 785314m - 785.314km
# Objective: 785255
# Route for vehicle 0:
#  0 ->  65 ->  43 ->  64 ->  13 ->  42 ->  37 ->  58 ->  36 ->  10 ->  63 ->  47 ->  38 ->  44 ->  25 ->  27 ->  35 ->  61 ->  20 ->  60 ->  16 ->  62 ->  32 ->  18 ->  21 ->  19 ->  34 ->  15 ->  7 ->  53 ->  46 ->  22 ->  31 ->  41 ->  40 ->  28 ->  30 ->  9 ->  54 ->  11 ->  24 ->  5 ->  12 ->  2 ->  39 ->  59 ->  1 ->  14 ->  29 ->  8 ->  6 ->  48 ->  49 ->  26 ->  51 ->  50 ->  23 ->  33 ->  45 ->  52 ->  56 ->  17 ->  4 ->  3 ->  57 ->  55 ->  67 ->  66 ->  76 ->  78 ->  75 ->  72 ->  73 ->  74 ->  79 ->  77 ->  80 ->  69 ->  70 ->  68 -> 71
# Distance of the route: 785255m
#
# Maximum of the route distances: 785255m - 785.255km
# Objective: 129532
# Route for vehicle 0:
#  16 ->  15 ->  14 ->  9 ->  7 ->  4 ->  6 ->  3 ->  13 ->  0 ->  2 ->  5 ->  11 ->  10 ->  12 ->  1 ->  8 -> 17
# Distance of the route: 129532m
#
# Maximum of the route distances: 129532m - 129.532km
# Objective: 129532
# Route for vehicle 0:
#  16 ->  15 ->  14 ->  9 ->  7 ->  4 ->  6 ->  3 ->  13 ->  0 ->  2 ->  5 ->  11 ->  10 ->  12 ->  1 ->  8 -> 17
# Distance of the route: 129532m
#
# Maximum of the route distances: 129532m - 129.532km
# Objective: 550077
# Route for vehicle 0:
#  17 ->  12 ->  10 ->  11 ->  9 ->  13 ->  72 ->  16 ->  18 ->  14 ->  15 ->  117 ->  115 ->  4 ->  0 ->  3 ->  122 ->  119 ->  1 ->  123 ->  6 ->  5 ->  8 ->  2 ->  7 ->  108 ->  92 ->  101 ->  44 ->  74 ->  78 ->  49 ->  77 ->  114 ->  110 ->  51 ->  58 ->  57 ->  112 ->  50 ->  71 ->  121 ->  120 ->  31 ->  116 ->  113 ->  97 ->  118 ->  40 ->  83 ->  38 ->  20 ->  111 ->  109 ->  79 ->  36 ->  45 ->  69 ->  55 ->  75 ->  54 ->  107 ->  100 ->  94 ->  84 ->  89 ->  90 ->  43 ->  66 ->  67 ->  25 ->  47 ->  30 ->  39 ->  68 ->  56 ->  27 ->  19 ->  32 ->  21 ->  48 ->  22 ->  29 ->  46 ->  28 ->  23 ->  26 ->  53 ->  24 ->  33 ->  34 ->  37 ->  41 ->  35 ->  73 ->  42 ->  87 ->  86 ->  62 ->  61 ->  82 ->  52 ->  91 ->  63 ->  103 ->  93 ->  104 ->  65 ->  70 ->  59 ->  60 ->  102 ->  96 ->  95 ->  80 ->  81 ->  98 ->  105 ->  76 ->  85 ->  88 ->  99 ->  64 -> 106
# ...
# Distance of the route: 103767m
#
# Maximum of the route distances: 103767m - 103.767km
# Objective: 103767
# Route for vehicle 0:
#  5 ->  14 ->  16 ->  18 ->  7 ->  0 ->  8 ->  12 ->  6 ->  13 ->  2 ->  15 ->  4 ->  1 ->  10 ->  3 ->  19 ->  23 ->  22 ->  21 ->  9 ->  11 ->  17 ->  20 ->  24 -> 25
# Distance of the route: 103767m
#
# Maximum of the route distances: 103767m - 103.767km
# Objective: 791207
# Route for vehicle 0:
#  49 ->  46 ->  45 ->  36 ->  32 ->  41 ->  23 ->  22 ->  24 ->  42 ->  30 ->  31 ->  26 ->  27 ->  34 ->  43 ->  40 ->  38 ->  37 ->  33 ->  44 ->  29 ->  39 ->  28 ->  35 ->  25 ->  47 ->  48 ->  19 ->  18 ->  13 ->  17 ->  16 ->  12 ->  9 ->  14 ->  15 ->  4 ->  5 ->  3 ->  0 ->  11 ->  6 ->  2 ->  1 ->  10 ->  8 ->  7 ->  147 ->  141 ->  51 ->  79 ->  66 ->  130 ->  69 ->  129 ->  73 ->  123 ->  87 ->  61 ->  108 ->  126 ->  128 ->  90 ->  62 ->  92 ->  102 ->  60 ->  154 ->  76 ->  75 ->  53 ->  100 ->  110 ->  59 ->  54 ->  127 ->  103 ->  74 ->  82 ->  97 ->  65 ->  77 ->  55 ->  56 ->  106 ->  71 ->  151 ->  83 ->  67 ->  58 ->  52 ->  88 ->  68 ->  119 ->  64 ->  91 ->  72 ->  89 ->  122 ->  112 ->  111 ->  57 ->  50 ->  63 ->  94 ->  85 ->  70 ->  96 ->  139 ->  105 ->  107 ->  113 ->  117 ->  80 ->  138 ->  145 ->  146 ->  20 ->  21 ->  150 ->  149 ->  143 ->  142 ->  99 ->  140 ->  86 ->  137 ->  132 ->  152 ->  95 ->  81 ->  134 ->  78 ->  120 ->  115 ->  84 ->  125 ->  124 ->  135 ->  121 ->  101 ->  98 ->  136 ->  133 ->  131 ->  109 ->  93 ->  114 ->  104 ->  116 ->  118 ->  144 ->  148 -> 153
# Distance of the route: 791207m
#
# Maximum of the route distances: 791207m - 791.207km
# Objective: 789184
# Route for vehicle 0:
#  49 ->  46 ->  45 ->  43 ->  40 ->  38 ->  37 ->  34 ->  27 ->  26 ->  31 ->  36 ->  32 ->  41 ->  23 ->  22 ->  24 ->  30 ->  42 ->  33 ->  44 ->  29 ->  39 ->  28 ->  35 ->  25 ->  47 ->  48 ->  19 ->  18 ->  13 ->  17 ->  16 ->  12 ->  9 ->  14 ->  15 ->  4 ->  5 ->  3 ->  0 ->  11 ->  6 ->  2 ->  1 ->  10 ->  8 ->  7 ->  147 ->  141 ->  51 ->  79 ->  66 ->  130 ->  69 ->  129 ->  73 ->  123 ->  87 ->  61 ->  108 ->  126 ->  128 ->  110 ->  59 ->  54 ->  127 ->  103 ->  74 ->  82 ->  97 ->  65 ->  77 ->  55 ->  56 ->  106 ->  71 ->  151 ->  83 ->  67 ->  58 ->  52 ->  88 ->  68 ->  119 ->  64 ->  91 ->  72 ->  89 ->  122 ->  112 ->  111 ->  57 ->  50 ->  63 ->  94 ->  70 ->  85 ->  100 ->  90 ->  62 ->  92 ->  102 ->  60 ->  154 ->  76 ->  53 ->  75 ->  96 ->  139 ->  105 ->  107 ->  113 ->  117 ->  80 ->  138 ->  145 ->  146 ->  20 ->  21 ->  150 ->  149 ->  143 ->  142 ->  99 ->  140 ->  86 ->  137 ->  132 ->  152 ->  95 ->  81 ->  134 ->  78 ->  120 ->  115 ->  84 ->  125 ->  124 ->  135 ->  121 ->  101 ->  98 ->  136 ->  133 ->  131 ->  109 ->  93 ->  114 ->  104 ->  116 ->  118 ->  144 ->  148 -> 153
# Distance of the route: 789184m
#
# Maximum of the route distances: 789184m - 789.184km
# Objective: 899470
# Route for vehicle 0:
#  73 ->  298 ->  53 ->  70 ->  141 ->  517 ->  356 ->  169 ->  405 ->  282 ->  15 ->  9 ->  411 ->  450 ->  167 ->  476 ->  112 ->  419 ->  144 ->  107 ->  159 ->  202 ->  266 ->  90 ->  28 ->  177 ->  160 ->  417 ->  197 ->  362 ->  13 ->  438 ->  423 ->  484 ->  453 ->  415 ->  43 ->  368 ->  276 ->  24 ->  232 ->  390 ->  79 ->  76 ->  31 ->  158 ->  216 ->  360 ->  37 ->  142 ->  20 ->  443 ->  213 ->  274 ->  481 ->  446 ->  288 ->  145 ->  235 ->  241 ->  322 ->  85 ->  157 ->  214 ->  363 ->  134 ->  133 ->  486 ->  184 ->  469 ->  114 ->  103 ->  12 ->  109 ->  260 ->  433 ->  426 ->  480 ->  487 ->  491 ->  64 ->  251 ->  46 ->  457 ->  296 ->  424 ->  27 ->  458 ->  268 ->  153 ->  598 ->  270 ->  428 ->  326 ->  74 ->  138 ->  196 ->  286 ->  139 ->  301 ->  313 ->  456 ->  358 ->  284 ->  149 ->  215 ->  96 ->  32 ->  408 ->  88 ->  198 ->  42 ->  10 ->  80 ->  71 ->  146 ->  234 ->  179 ->  473 ->  431 ->  4 ->  193 ->  448 ->  294 ->  5 ->  494 ->  168 ->  86 ->  425 ->  98 ->  386 ->  351 ->  111 ->  220 ->  223 ->  156 ->  334 ->  343 ->  345 ->  399 ->  264 ->  507 ->  324 ->  348 ->  287 ->  302 ->  331 ->  2 ->  509 ->  398 ->  265 ->  505 ->  116 ->  316 ->  229 ->  261 ->  430 ->  22 ->  370 ->  492 ->  416 ->  140 ->  336 ->  451 ->  154 ->  403 ->  122 ->  240 ->  39 ->  61 ->  267 ->  217 ->  273 ->  194 ->  221 ->  255 ->  500 ->  461 ->  26 ->  175 ->  8 ->  277 ->  81 ->  495 ->  35 ->  613 ->  367 ->  498 ->  595 ->  55 ->  299 ->  124 ->  180 ->  188 ->  418 ->  69 ->  242 ->  410 ->  445 ->  143 ->  18 ->  289 ->  162 ->  608 ->  619 ->  604 ->  442 ->  231 ->  596 ->  572 ->  579 ->  556 ->  65 ->  554 ->  528 ->  537 ->  597 ->  544 ->  535 ->  551 ->  557 ->  541 ->  569 ->  68 ->  526 ->  538 ->  549 ->  605 ->  592 ->  577 ->  576 ->  550 ->  524 ->  72 ->  601 ->  543 ->  533 ->  523 ->  589 ->  594 ->  452 ->  108 ->  195 ->  474 ->  463 ->  588 ->  614 ->  610 ->  615 ->  378 ->  161 ->  444 ->  269 ->  407 ->  152 ->  239 ->  137 ->  110 ->  41 ->  218 ->  206 ->  233 ->  482 ->  60 ->  225 ->  135 ->  315 ->  465 ->  207 ->  222 ->  200 ->  125 ->  40 ->  454 ->  78 ->  460 ->  191 ->  338 ->  126 ->  283 ->  440 ->  497 ->  243 ->  253 ->  113 ->  401 ->  119 ->  325 ->  293 ->  254 ->  45 ->  285 ->  58 ->  178 ->  422 ->  278 ->  205 ->  332 ->  371 ->  247 ->  250 ->  366 ->  201 ->  63 ->  14 ->  212 ->  355 ->  7 ->  510 ->  307 ->  375 ->  123 ->  186 ->  52 ->  34 ->  339 ->  478 ->  170 ->  515 ->  347 ->  310 ->  420 ->  342 ->  309 ->  228 ->  479 ->  382 ->  396 ->  262 ->  182 ->  245 ->  6 ->  434 ->  449 ->  394 ->  421 ->  437 ->  272 ->  300 ->  128 ->  377 ->  101 ->  38 ->  147 ->  165 ->  464 ->  120 ->  121 ->  352 ->  224 ->  357 ->  49 ->  93 ->  402 ->  94 ->  115 ->  82 ->  317 ->  33 ->  439 ->  381 ->  50 ->  211 ->  328 ->  412 ->  395 ->  447 ->  323 ->  291 ->  404 ->  340 ->  25 ->  131 ->  516 ->  314 ->  210 ->  303 ->  258 ->  504 ->  312 ->  365 ->  252 ->  341 ->  466 ->  349 ->  320 ->  387 ->  374 ->  329 ->  304 ->  311 ->  257 ->  514 ->  290 ->  117 ->  189 ->  99 ->  383 ->  237 ->  236 ->  29 ->  503 ->  297 ->  369 ->  506 ->  508 ->  372 ->  477 ->  204 ->  327 ->  364 ->  118 ->  392 ->  512 ->  181 ->  406 ->  319 ->  354 ->  321 ->  102 ->  163 ->  0 ->  485 ->  244 ->  305 ->  187 ->  256 ->  350 ->  335 ->  337 ->  511 ->  333 ->  280 ->  318 ->  513 ->  259 ->  16 ->  100 ->  292 ->  271 ->  400 ->  227 ->  1 ->  51 ->  19 ->  92 ->  36 ->  275 ->  353 ->  176 ->  208 ->  127 ->  346 ->  455 ->  59 ->  97 ->  501 ->  518 ->  226 ->  499 ->  488 ->  30 ->  132 ->  66 ->  602 ->  545 ->  617 ->  87 ->  385 ->  470 ->  155 ->  77 ->  173 ->  105 ->  441 ->  427 ->  67 ->  83 ->  174 ->  475 ->  219 ->  62 ->  468 ->  380 ->  91 ->  483 ->  192 ->  471 ->  21 ->  308 ->  11 ->  263 ->  136 ->  391 ->  48 ->  54 ->  230 ->  435 ->  56 ->  306 ->  183 ->  459 ->  330 ->  249 ->  397 ->  199 ->  361 ->  384 ->  373 ->  190 ->  172 ->  462 ->  16 ...
# Distance of the route: 899470m
#
# Maximum of the route distances: 899470m - 899.47km
# Objective: 904840
# Route for vehicle 0:
#  73 ->  298 ->  53 ->  70 ->  141 ->  517 ->  356 ->  169 ->  405 ->  282 ->  480 ->  426 ->  487 ->  491 ->  64 ->  251 ->  46 ->  457 ->  296 ->  433 ->  260 ->  109 ->  12 ->  138 ->  74 ->  424 ->  27 ->  458 ->  268 ->  153 ->  596 ->  572 ->  579 ->  556 ->  65 ->  554 ->  528 ->  537 ->  597 ->  544 ->  535 ->  551 ->  557 ->  541 ->  569 ->  68 ->  526 ->  538 ->  549 ->  605 ->  592 ->  577 ->  576 ->  550 ->  524 ->  72 ->  601 ->  543 ->  533 ->  523 ->  589 ->  594 ->  452 ->  108 ->  465 ->  207 ->  278 ->  422 ->  205 ->  332 ->  267 ->  478 ->  339 ->  186 ->  123 ->  375 ->  307 ->  510 ->  52 ->  34 ->  310 ->  347 ->  515 ->  170 ->  229 ->  261 ->  116 ->  316 ->  348 ->  287 ->  302 ->  331 ->  2 ->  509 ->  398 ->  265 ->  505 ->  98 ->  425 ->  370 ->  492 ->  416 ->  22 ->  430 ->  336 ->  140 ->  451 ->  154 ->  403 ->  122 ->  240 ->  39 ->  61 ->  217 ->  273 ->  194 ->  221 ->  255 ->  500 ->  461 ->  26 ->  175 ->  8 ->  277 ->  81 ->  495 ->  35 ->  613 ->  367 ->  498 ->  619 ->  604 ->  231 ->  442 ->  162 ->  608 ->  595 ->  55 ->  299 ->  124 ->  180 ->  188 ->  418 ->  69 ->  242 ->  410 ->  445 ->  143 ->  18 ->  289 ->  598 ->  270 ->  428 ->  326 ->  32 ->  96 ->  408 ->  88 ->  198 ->  42 ->  10 ->  80 ->  71 ->  146 ->  234 ->  179 ->  473 ->  431 ->  4 ->  193 ->  448 ->  294 ->  5 ->  494 ->  168 ->  86 ->  85 ->  322 ->  386 ->  351 ->  111 ->  220 ->  223 ->  156 ->  334 ->  327 ->  364 ->  118 ->  392 ->  512 ->  181 ->  406 ->  319 ->  354 ->  321 ->  102 ->  163 ->  0 ->  485 ->  244 ->  187 ->  256 ->  350 ->  335 ->  513 ->  259 ->  318 ->  280 ->  337 ->  511 ->  333 ->  305 ->  54 ->  230 ->  48 ->  391 ->  136 ->  263 ->  459 ->  330 ->  249 ->  397 ->  183 ->  306 ->  56 ->  435 ->  291 ->  404 ->  340 ->  25 ->  131 ->  516 ->  314 ->  210 ->  303 ->  258 ->  504 ->  312 ->  365 ->  252 ->  466 ->  341 ->  439 ->  381 ->  50 ->  211 ->  328 ->  412 ->  395 ->  323 ->  447 ->  359 ->  502 ->  376 ->  389 ->  150 ->  47 ->  413 ->  185 ->  203 ->  414 ->  279 ->  238 ->  57 ->  199 ->  11 ->  308 ->  21 ->  471 ->  16 ->  202 ->  266 ->  90 ->  28 ->  177 ->  160 ->  417 ->  197 ->  362 ->  13 ->  438 ->  423 ->  484 ->  453 ->  415 ->  43 ->  368 ->  276 ->  24 ->  232 ->  390 ->  79 ->  76 ->  31 ->  158 ->  216 ->  360 ->  37 ->  142 ->  20 ->  443 ->  213 ->  274 ->  481 ->  446 ->  288 ->  145 ->  235 ->  241 ->  157 ->  214 ->  363 ->  134 ->  133 ->  486 ->  184 ->  215 ->  149 ->  284 ->  358 ->  456 ->  313 ->  196 ->  286 ->  139 ->  301 ->  103 ->  114 ->  469 ->  167 ->  476 ->  450 ->  411 ->  112 ->  419 ->  144 ->  107 ->  159 ->  100 ->  292 ->  271 ->  400 ->  227 ->  1 ->  51 ->  19 ->  92 ->  36 ->  275 ->  353 ->  176 ->  208 ->  455 ->  346 ->  127 ->  9 ->  15 ->  59 ->  97 ->  501 ->  518 ->  226 ->  499 ->  488 ->  67 ->  77 ->  173 ->  155 ->  30 ->  132 ->  66 ->  602 ->  545 ->  617 ->  87 ->  385 ->  470 ->  105 ->  441 ->  427 ->  83 ->  174 ->  475 ->  219 ->  62 ->  468 ->  380 ->  91 ->  483 ->  192 ->  361 ->  384 ->  373 ->  190 ->  172 ->  462 ->  166 ->  248 ->  44 ->  472 ->  129 ->  379 ->  89 ->  130 ->  489 ->  344 ->  171 ->  151 ->  246 ->  388 ->  493 ->  432 ->  209 ->  429 ->  393 ->  281 ->  581 ->  496 ->  436 ->  95 ->  84 ->  104 ->  534 ->  17 ->  164 ->  600 ->  467 ->  542 ->  525 ->  553 ->  547 ->  606 ->  607 ->  548 ->  611 ->  295 ->  539 ->  618 ->  587 ->  520 ->  575 ->  573 ->  558 ->  584 ->  106 ->  75 ->  574 ->  23 ->  546 ->  603 ->  527 ->  585 ->  580 ->  615 ->  378 ->  161 ->  444 ->  269 ->  120 ->  121 ->  352 ->  224 ->  357 ->  49 ->  93 ->  402 ->  94 ->  33 ->  317 ->  82 ->  115 ->  165 ->  147 ->  38 ->  113 ->  253 ->  243 ->  497 ->  283 ->  440 ->  464 ->  191 ->  460 ->  78 ->  454 ->  45 ->  254 ->  338 ->  126 ->  293 ->  325 ->  119 ->  401 ->  101 ->  377 ->  128 ->  300 ->  272 ->  437 ->  421 ->  394 ->  449 ->  434 ->  6 ->  349 ->  320 ->  387 ->  374 ->  329 ->  304 ->  311 ->  257 ->  5 ...
# Distance of the route: 904840m
#
# Maximum of the route distances: 904840m - 904.84km
# Objective: 250067
# Route for vehicle 0:
#  76 ->  75 ->  77 ->  74 ->  73 ->  50 ->  42 ->  38 ->  64 ->  18 ->  49 ->  27 ->  15 ->  23 ->  67 ->  17 ->  19 ->  5 ->  43 ->  4 ->  44 ->  32 ->  6 ->  11 ->  28 ->  36 ->  33 ->  61 ->  57 ->  9 ->  48 ->  59 ->  26 ->  52 ->  25 ->  10 ->  20 ->  54 ->  40 ->  72 ->  41 ->  13 ->  0 ->  71 ->  62 ->  45 ->  12 ->  8 ->  24 ->  16 ->  2 ->  31 ->  1 ->  34 ->  3 ->  22 ->  7 ->  21 ->  46 ->  66 ->  51 ->  29 ->  53 ->  58 ->  35 ->  63 ->  60 ->  69 ->  56 ->  55 ->  68 ->  30 ->  14 ->  39 ->  70 ->  65 ->  37 ->  47 ->  78 -> 79
# Distance of the route: 250067m
#
# Maximum of the route distances: 250067m - 250.067km
# Objective: 244952
# Route for vehicle 0:
#  76 ->  75 ->  77 ->  74 ->  73 ->  50 ->  42 ->  38 ->  64 ->  18 ->  49 ->  25 ->  10 ->  20 ->  54 ->  8 ->  12 ->  45 ->  62 ->  71 ->  0 ->  13 ->  40 ->  72 ->  41 ->  2 ->  31 ->  1 ->  24 ->  16 ->  34 ->  3 ->  22 ->  7 ->  21 ->  46 ->  66 ->  51 ->  29 ->  53 ->  58 ->  43 ->  4 ->  44 ->  32 ->  5 ->  19 ->  17 ->  36 ->  28 ->  6 ->  11 ->  33 ->  61 ->  57 ->  9 ->  48 ->  59 ->  26 ->  52 ->  27 ->  67 ->  23 ->  15 ->  30 ->  68 ->  55 ->  56 ->  69 ->  35 ->  63 ->  60 ->  14 ->  39 ->  70 ->  65 ->  37 ->  47 ->  78 -> 79
# Distance of the route: 244952m
#
# Maximum of the route distances: 244952m - 244.952km
# Objective: 435269
# Route for vehicle 0:
#  98 ->  89 ->  79 ->  95 ->  96 ->  86 ->  85 ->  88 ->  72 ->  80 ->  91 ->  77 ->  57 ->  84 ->  92 ->  94 ->  81 ->  93 ->  83 ->  73 ->  70 ->  64 ->  62 ->  22 ->  43 ->  47 ->  34 ->  45 ->  59 ->  13 ->  19 ->  54 ->  56 ->  66 ->  53 ->  36 ->  24 ->  6 ->  7 ->  51 ->  30 ->  16 ->  8 ->  14 ->  17 ->  11 ->  29 ->  69 ->  27 ->  55 ->  37 ->  50 ->  31 ->  60 ->  5 ->  2 ->  21 ->  10 ->  9 ->  23 ->  4 ->  0 ->  3 ->  1 ->  52 ->  20 ->  67 ->  12 ->  32 ->  46 ->  48 ->  74 ->  28 ->  41 ->  65 ->  40 ->  35 ->  58 ->  18 ->  63 ->  71 ->  39 ->  49 ->  68 ->  61 ->  42 ->  15 ->  33 ->  26 ->  25 ->  44 ->  38 ->  78 ->  82 ->  76 ->  75 ->  87 ->  97 ->  90 ->  99 ->  100 -> 101
# Distance of the route: 435269m
#
# Maximum of the route distances: 435269m - 435.269km
# Objective: 444486
# Route for vehicle 0:
#  98 ->  89 ->  69 ->  27 ->  55 ->  37 ->  50 ->  31 ->  60 ->  5 ->  4 ->  23 ->  0 ->  9 ->  2 ->  21 ->  10 ->  29 ->  11 ->  17 ->  14 ->  8 ->  3 ->  1 ->  20 ->  67 ->  52 ->  16 ->  30 ->  51 ->  7 ->  6 ->  24 ->  36 ->  53 ->  66 ->  56 ->  54 ->  19 ->  13 ->  59 ->  45 ->  34 ->  47 ->  43 ->  22 ->  62 ->  64 ->  70 ->  12 ->  32 ->  46 ->  48 ->  74 ->  28 ->  41 ->  65 ->  40 ->  35 ->  58 ->  18 ->  63 ->  71 ->  39 ->  49 ->  68 ->  61 ->  42 ->  15 ->  33 ->  26 ->  25 ->  44 ->  38 ->  78 ->  82 ->  76 ->  75 ->  87 ->  97 ->  83 ->  73 ->  72 ->  80 ->  88 ->  85 ->  79 ->  95 ->  96 ->  86 ->  94 ->  92 ->  84 ->  57 ->  77 ->  91 ->  93 ->  81 ->  90 ->  99 ->  100 -> 101
# Distance of the route: 444486m
#
# Maximum of the route distances: 444486m - 444.486km
# Objective: 336176
# Route for vehicle 0:
#  9 ->  16 ->  15 ->  14 ->  1 ->  19 ->  3 ->  17 ->  6 ->  18 ->  10 ->  5 ->  4 ->  20 ->  13 ->  0 ->  12 ->  2 ->  8 ->  7 ->  11 ->  21 ->  23 ->  24 ->  25 ->  22 ->  26 -> 27
# Distance of the route: 336176m
#
# Maximum of the route distances: 336176m - 336.176km
# Objective: 336176
# Route for vehicle 0:
#  9 ->  16 ->  15 ->  14 ->  1 ->  19 ->  3 ->  17 ->  6 ->  18 ->  10 ->  5 ->  4 ->  20 ->  13 ->  0 ->  12 ->  2 ->  8 ->  7 ->  11 ->  21 ->  23 ->  24 ->  25 ->  22 ->  26 -> 27
# Distance of the route: 336176m
#
# Maximum of the route distances: 336176m - 336.176km
# Objective: 657181
# Route for vehicle 0:
#  1 ->  38 ->  37 ->  4 ->  2 ->  57 ->  54 ->  51 ->  59 ->  0 ->  60 ->  58 ->  9 ->  45 ->  43 ->  44 ->  50 ->  40 ->  47 ->  48 ->  46 ->  56 ->  42 ->  39 ->  41 ->  49 ->  53 ->  55 ->  34 ->  35 ->  14 ->  16 ->  15 ->  27 ->  18 ->  17 ->  21 ->  25 ->  24 ->  26 ->  20 ->  19 ->  13 ->  12 ->  23 ->  30 ->  22 ->  11 ->  29 ->  10 ->  28 ->  32 ->  31 ->  33 ->  36 ->  5 ->  52 ->  6 ->  8 ->  3 -> 7
# Distance of the route: 657181m
#
# Maximum of the route distances: 657181m - 657.181km
# Objective: 657181
# Route for vehicle 0:
#  1 ->  38 ->  37 ->  4 ->  2 ->  57 ->  54 ->  51 ->  59 ->  0 ->  60 ->  58 ->  9 ->  45 ->  43 ->  44 ->  50 ->  40 ->  47 ->  48 ->  46 ->  56 ->  42 ->  39 ->  41 ->  49 ->  53 ->  55 ->  34 ->  35 ->  14 ->  16 ->  15 ->  27 ->  18 ->  17 ->  21 ->  25 ->  24 ->  26 ->  20 ->  19 ->  13 ->  12 ->  23 ->  30 ->  22 ->  11 ->  29 ->  10 ->  28 ->  32 ->  31 ->  33 ->  36 ->  5 ->  52 ->  6 ->  8 ->  3 -> 7
# Distance of the route: 657181m
#
# Maximum of the route distances: 657181m - 657.181km
# 33528931
# 59654366m - 59654.366km
# 55951863m - 55951.863km

# %%
create_map_from_graph(full_graph)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea3d8c0ecb4c37599a8abebf88d81bf7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea3d8c0ecb4c37599a8abebf88d81bf7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea3d8c0ecb4c37599a8abebf88d81bf7 = L.map(
#                 &quot;map_ea3d8c0ecb4c37599a8abebf88d81bf7&quot;,
#                 {
#                     center: [56.322, 90.004],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dec6c7c7865f9e65d403dcf07e209a6b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ea3d8c0ecb4c37599a8abebf88d81bf7);
#
#
#             var circle_marker_5ecf804993765b1ebf4471e6a73cfac5 = L.circleMarker(
#                 [42.551929, 47.875446],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ea3d8c0ecb4c37599a8abebf88d81bf7);
#
#
#             var circle_marker_1f0745498d2cb09563d1d76549949f1b = L.circleMarker(
#                 [42.572225, 47.866228],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ea3d8c0ecb4c37599a8abebf88d81bf7);
#
#
#             var circle_marker_2e16b1830019ec077563f3f67c042e6d = L.circleMarker(
#                 [42.88598, 47.630855],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ea3d8c0ecb4c37599a8abebf88d81bf7);
#
#
#             var circle_marker_a61fa997b0f181090ce5cc29d15308ce = L.circleMarker(
#                 [42.88606, 47.634247],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ea3d8c0ecb4c37599a8abebf88d81bf7);
#
#
#             var circle_marker_93e7b5816643e2b6b972482920e89686 = L.circleMarker(
#                 [42.891665, 47.640831],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ea3d8c0ecb4c37599a8abebf88d81bf7);
#
#
#             var circle_marker_189b54e932ef9bd9dd374fb184f9d173 = L.circleMarker(
#                 [42.892802, 47.630877],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ea3d8c0ecb4c37599a8abebf88d81bf7);
#
#
#             var circle_marker_118b63bbba3c6ded3309b8d046722f1c = L.circleMarker(
#                 [42.94

# %%
for i in full_graph.edges(data=True):
  print(i)

# %%
# Карта с медоидами кластеров
m = folium.Map(location=[56.322, 90.004], zoom_start=3)

node_positions = {}
node_positions = {node: [test.nodes[node]['lat'], test.nodes[node]['lon'], test.nodes[node]['cluster_number']] for node in test.nodes()}
for node, pos in node_positions.items():
    folium.CircleMarker(location=pos[:2], radius=5, color='blue', fill=True, popup=f'{pos[2]}').add_to(m)


for u, v, weight in test.edges(data=True):
    weight = weight['weight']
    pos_u = node_positions[u]
    pos_v = node_positions[v]
m

# %% [markdown]
# # ***Тестовая область***

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/ВУЗ/ITMO/NIR/random_points.csv')
# df = pd.read_csv('random_points.csv')
df = df.dropna()[['Долгота', 'Широта']].reset_index(drop=True)
df.columns = ['lon', 'lat']

# %%
work_df = df[::250].copy()                # Если брать каждую (127*целое число) точку, то я захватываю всю территорию России
work_df = work_df.reset_index(drop=True)
G = create_graph_from_coordinates(work_df)
# Out:
# Progress: 100%|██████████| 485/485 [00:01<00:00, 393.17it/s]

# %% [markdown]
# ### Глобальный граф

# %%
start_time = time.time()

timeout=30
routes, v = search_optimal_path(G, timeout=timeout)
solver_graph = create_graph_after_solver(G, routes)


end_time = time.time()
execution_time = end_time - start_time
print(f"Время выполнения: {execution_time:.2f} секунд")
print(f'{v//1000} km')
print(len(G.nodes()))
# Out:
# Время выполнения: 30.99 секунд
# 33287 km
# 485

# %% [markdown]
# ### Локальный граф

# %%
dista = []
for i in range(5, 6):
    start_time = time.time()
    n_cl = i
    timeout = 2
    # timeout = timeout // (n_cl*8)
    # print(timeout)

    work_graph, medoids = kmedoids_clustering_for_graph(G, n_cl)
    med_graph = G.subgraph(medoids)
    cluster_routes, b = search_optimal_path(med_graph, clusters=True, timeout=1)

    d = {}
    correct_clusters = []
    correct_nodes = []
    for i, node in enumerate(med_graph.nodes(data=True), 0):
        d[i] = (node[0], node[1]['cluster_number']) # {index: (номер ноды, номер кластера)}
    for i in cluster_routes:
        # перебирая словарь, выделяем список кластеров по порядку и нод по порядку.
        # Кластеры нужны, чтобы по ним проходиться i и i+1
        # Ноды нужны для функции create_graph_after_solver, чтобы выделить последовательность пути
        correct_nodes.append(d[i][0])
        correct_clusters.append(d[i][1])

    transition, extreme_points = search_min_weight_path(work_graph, correct_clusters)
    full_graph = nx.Graph()
    full_path = 0
    for i in range(len(correct_clusters)):
        selected_nodes = [node for node, attr in work_graph.nodes(data=True) if attr['cluster_number'] == correct_clusters[i]]
        sub = work_graph.subgraph(selected_nodes).copy()
        cluster_routes_sub, path = search_optimal_path(sub, clusters=True, timeout=timeout, extreme=extreme_points[correct_clusters[i]])
        full_path += path
        d_sub = {}
        correct_clusters_sub = []
        correct_nodes_sub = []
        for i, node in enumerate(sub.nodes(data=True), 0):
            d_sub[i] = (node[0], node[1]['cluster_number']) # {index: (номер ноды, номер кластера)}

        for i in cluster_routes_sub:
            # перебирая словарь, выделяем список кластеров по порядку и нод по порядку.
            # Кластеры нужны, чтобы по ним проходиться i и i+1
            # Ноды нужны для функции create_graph_after_solver, чтобы выделить последовательность пути
            correct_nodes_sub.append(d_sub[i][0])
            correct_clusters_sub.append(d_sub[i][1])
        full_graph = create_graph_after_solver_full(sub, full_graph, correct_nodes_sub)
    for j, i in transition.items():
        if work_graph.has_edge(i[0], i[1]) and j != transition[(correct_clusters[-1], correct_clusters[0])]:
            full_path += work_graph.get_edge_data(i[0], i[1])['weight']
            # Копирование атрибутов ребра из оригинального графа G в новый граф new_G
            full_graph.add_edge(i[0], i[1], **work_graph.get_edge_data(i[0], i[1]))
    full_graph.remove_edge(*transition[(correct_clusters[-1], correct_clusters[0])])
    print(f'{full_path}m - {full_path//1000} km')
    # print(f"{full_path - work_graph.get_edge_data(*transition[(correct_clusters[-2], correct_clusters[-1])])['weight']}m - {(full_path - work_graph.get_edge_data(*transition[(correct_clusters[-2], correct_clusters[-1])])['weight'])//1000} km")
    print('Количество кластеров: ',n_cl)
    end_time = time.time()
    execution_time = end_time - start_time
    print(f"Время выполнения: {execution_time:.2f} секунд", '\n')
    print(len(G.nodes()))
# Out:
# 41538643m - 41538 km
# Количество кластеров:  5
# Время выполнения: 13.68 секунд
#
# 485

# %%
create_map_from_graph(G)

# %%
create_map_from_graph(solver_graph)

# %%
create_map_from_graph(full_graph)

# %%
create_map_from_graph(med_graph)

# %%
def create_map_from_graph_with_clusters_color(G):
    '''Создание интерактивной карты из графа. Граф должен иметь lat= и lon='''

    m = folium.Map(location=[56.322, 90.004], zoom_start=3)

    node_positions = {}
    node_positions = {node: (G.nodes[node]['lat'], G.nodes[node]['lon'], G.nodes[node]['cluster_number']) for node in G.nodes()}
    cluster_colors = {
    0: 'purple',
    1: 'red',
    2: 'blue',
    3: 'green',
    4: 'orange',}


    for node, pos in node_positions.items():
        cluster_number = pos[2]
        popup_info = f"Node: {node}, Cluster: {cluster_number}"
        color = cluster_colors.get(cluster_number, 'black')  # Используйте черный цвет по умолчанию
        folium.CircleMarker(location=pos[:2], radius=3, color=color, fill=True, popup=popup_info).add_to(m)


    for u, v, weight in G.edges(data=True):
        weight = weight['weight']
        pos_u = node_positions[u]
        pos_v = node_positions[v]
        if not weight:
            folium.PolyLine(locations=[pos_u[:2], pos_v[:2]], color='red', weight=0.9, opacity=0.5).add_to(m)
        else:
            folium.PolyLine(locations=[pos_u[:2], pos_v[:2]], color='black', weight=1.5, opacity=0.5).add_to(m)

    return m

# %%
create_map_from_graph_with_clusters_color(full_graph)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8a694a58c531578fb717c19fc301e8e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8a694a58c531578fb717c19fc301e8e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8a694a58c531578fb717c19fc301e8e7 = L.map(
#                 &quot;map_8a694a58c531578fb717c19fc301e8e7&quot;,
#                 {
#                     center: [56.322, 90.004],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec9c411a24272b2206b8f61c2c97411d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8a694a58c531578fb717c19fc301e8e7);
#
#
#             var circle_marker_927215bb18cef13de12095edae612b11 = L.circleMarker(
#                 [51.51566, 81.204474],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8a694a58c531578fb717c19fc301e8e7);
#
#
#         var popup_215a760139b4a6f3bd58823660e143f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fa7886bba975b80c1a1d71929575b688 = $(`&lt;div id=&quot;html_fa7886bba975b80c1a1d71929575b688&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;534&lt;/div&gt;`)[0];
#                 popup_215a760139b4a6f3bd58823660e143f0.setContent(html_fa7886bba975b80c1a1d71929575b688);
#
#
#
#         circle_marker_927215bb18cef13de12095edae612b11.bindPopup(popup_215a760139b4a6f3bd58823660e143f0)
#         ;
#
#
#
#
#             var circle_marker_2fb55c08acb64b2651bbc2d2a0c19479 = L.circleMarker(
#                 [52.900217, 83.547602],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8a694a58c531578fb717c19fc301e8e7);
#
#
#         var popup_83e147846169569d1a99a1d03c6d913d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2e01c492e6893f7bc951b2dbdf221ba4 = $(`&lt;div id=&quot;html_2e01c492e6893f7bc951b2dbdf221ba4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;46&lt;/div&gt;`)[0];
#                 popup_83e147846169569d1a99a1d03c6d913d.setContent(html_2e01c492e6893f7bc951b2dbdf221ba4);
#
#
#
#         circle_marker_2fb55c08acb64b2651bbc2d2a0c19479.bindPopup(popup_83e147846169569d1a99a1d03c6d913d)
#         ;
#
#
#
#
#             var circle_marker_e295b15369826b1204f5b9fa46b3a0fb = L.circleMarker(
#                 [53.335948, 83.667509],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8a694a58c531578fb717c19fc301e8e7);
#
#
#         var popup_0cc49003c9131f9e0b2accd555a5930e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ac1f9bf1cf2c47a4ab630f6306ef478e = $(`&lt;div id=&quot;html_ac1f9bf1cf2c47a4ab630f6306ef478e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;37&lt;/div&gt;`)[0];
#                 popup_0cc49003c9131f9e0b2accd555a5930e.setContent(html_ac1f9bf1cf2c47a4ab630f6306ef478e);
#
#
#
#         circle_marker_e295b15369826b1204f5b9fa46b3a0fb.bindPopup(popup_0cc49003c9131f9e0b2accd555a5930e)
#         ;
#
#
#
#
#             var circle_marker_2ec2e13cad8081b25bf06feb7303c9c4 = L.circleMarker(
#                 [53.342681, 83.679322],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quo
